# %% [markdown]
# # The Story of Cereals

# %%
import pandas as pd

# %% [markdown]
# Every story begins with the preperation lets take tiffen preperation, in that tiffen we will have many different dishes with many choices but the main goal is to have a good and healthy food for our body . Food contains many things like ....
# - fats
# - proteins
# - carbs
# - sodium
# - potash
# - vitamins and soo on ....
# Now we need to find which food or which ceral is good for our health
# - Most cereals have less than 120 calories.
# - More cereals have high sugar levels.
# - More cereals have fat contant in it
# - Some cereals have high or low fibre content
# - We can calculate or visualize that our breakfast conatins how much amt of fat content sugar content fibre content and soo on ...

# %%
df=pd.read_csv('/Users/lalithavemalapalli/Downloads/cereal.csv')
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# To first prepare the tiffen we need to check what are the availabel things and then we need to clean them

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
df.isnull()
# Out:
#      name    mfr   type  calories  protein    fat  sodium  fiber  carbo  \
# 0   False  False  False     False    False  False   False  False  False
# 1   False  False  False     False    False  False   False  False  False
# 2   False  False  False     False    False  False   False  False  False
# 3   False  False  False     False    False  False   False  False  False
# 4   False  False  False     False    False  False   False  False  False
# ..    ...    ...    ...       ...      ...    ...     ...    ...    ...
# 72  False  False  False     False    False  False   False  False  False
# 73  False  False  False     False    False  False   False  False  False
# 74  False  False  False     False    False  False   False  False  False
# 75  False  False  False     False    False  False   False  False  False
# 76  False  False  False     False    False  False   False  False  False
#
#     sugars  potass  vitamins  shelf  weight   cups  rating
# ...

# %%
df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
group=df.groupby([df['mfr'],df['name']])
group

# %% [markdown]
# Now we need to count the number of calories of each cereal

# %%
counting=df['calories'].groupby([df['mfr'],df['name']]).count().reset_index(name='calories_count')
counting
# Out:
#    mfr                               name  calories_count
# 0    A                              Maypo               1
# 1    G            Apple Cinnamon Cheerios               1
# 2    G                            Basic 4               1
# 3    G                           Cheerios               1
# 4    G              Cinnamon Toast Crunch               1
# ..  ..                                ...             ...
# 72   R                        Double Chex               1
# 73   R   Muesli Raisins; Dates; & Almonds               1
# 74   R  Muesli Raisins; Peaches; & Pecans               1
# 75   R                          Rice Chex               1
# 76   R                         Wheat Chex               1
#
# [77 rows x 3 columns]

# %% [markdown]
# Now we need to count the number of proteins in each ceral

# %%
counting1=df['protein'].groupby([df['mfr'],df['name']]).count().reset_index(name='protein_count')
counting1
# Out:
#    mfr                               name  protein_count
# 0    A                              Maypo              1
# 1    G            Apple Cinnamon Cheerios              1
# 2    G                            Basic 4              1
# 3    G                           Cheerios              1
# 4    G              Cinnamon Toast Crunch              1
# ..  ..                                ...            ...
# 72   R                        Double Chex              1
# 73   R   Muesli Raisins; Dates; & Almonds              1
# 74   R  Muesli Raisins; Peaches; & Pecans              1
# 75   R                          Rice Chex              1
# 76   R                         Wheat Chex              1
#
# [77 rows x 3 columns]

# %% [markdown]
# now we need to check the average calories of each cereal grouped by the name and mfr

# %%
counting=df['calories'].groupby([df['mfr'],df['name']]).mean().reset_index(name='calories_avg')
counting
# Out:
#    mfr                               name  calories_avg
# 0    A                              Maypo         100.0
# 1    G            Apple Cinnamon Cheerios         110.0
# 2    G                            Basic 4         130.0
# 3    G                           Cheerios         110.0
# 4    G              Cinnamon Toast Crunch         120.0
# ..  ..                                ...           ...
# 72   R                        Double Chex         100.0
# 73   R   Muesli Raisins; Dates; & Almonds         150.0
# 74   R  Muesli Raisins; Peaches; & Pecans         150.0
# 75   R                          Rice Chex         110.0
# 76   R                         Wheat Chex         100.0
#
# [77 rows x 3 columns]

# %%
counting1=df['protein'].groupby([df['mfr'],df['name']]).mean().reset_index(name='protein_avg')
counting1
# Out:
#    mfr                               name  protein_avg
# 0    A                              Maypo          4.0
# 1    G            Apple Cinnamon Cheerios          2.0
# 2    G                            Basic 4          3.0
# 3    G                           Cheerios          6.0
# 4    G              Cinnamon Toast Crunch          1.0
# ..  ..                                ...          ...
# 72   R                        Double Chex          2.0
# 73   R   Muesli Raisins; Dates; & Almonds          4.0
# 74   R  Muesli Raisins; Peaches; & Pecans          4.0
# 75   R                          Rice Chex          1.0
# 76   R                         Wheat Chex          3.0
#
# [77 rows x 3 columns]

# %% [markdown]
# Here we are checking which cereal consumes maximum protien

# %%
counting1=df['protein'].groupby([df['mfr'],df['name']]).max().reset_index(name='protein_max')
counting1
# Out:
#    mfr                               name  protein_max
# 0    A                              Maypo            4
# 1    G            Apple Cinnamon Cheerios            2
# 2    G                            Basic 4            3
# 3    G                           Cheerios            6
# 4    G              Cinnamon Toast Crunch            1
# ..  ..                                ...          ...
# 72   R                        Double Chex            2
# 73   R   Muesli Raisins; Dates; & Almonds            4
# 74   R  Muesli Raisins; Peaches; & Pecans            4
# 75   R                          Rice Chex            1
# 76   R                         Wheat Chex            3
#
# [77 rows x 3 columns]

# %% [markdown]
# Here we are checking which cereal contains the minimum protien

# %%
counting1=df['protein'].groupby([df['mfr'],df['name']]).min().reset_index(name='protein_min')
counting1
# Out:
#    mfr                               name  protein_min
# 0    A                              Maypo            4
# 1    G            Apple Cinnamon Cheerios            2
# 2    G                            Basic 4            3
# 3    G                           Cheerios            6
# 4    G              Cinnamon Toast Crunch            1
# ..  ..                                ...          ...
# 72   R                        Double Chex            2
# 73   R   Muesli Raisins; Dates; & Almonds            4
# 74   R  Muesli Raisins; Peaches; & Pecans            4
# 75   R                          Rice Chex            1
# 76   R                         Wheat Chex            3
#
# [77 rows x 3 columns]

# %% [markdown]
# counting the values of the shelf column

# %%
df['shelf'].value_counts()
# Out:
# shelf
# 3    36
# 2    21
# 1    20
# Name: count, dtype: int64

# %% [markdown]
# Finding the best cerels with high rating and low sugar content

# %%
a=df[(df['rating'] > 60) & (df['sugars'] < 5)]
a
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 54                Puffed Rice   Q    C        50        1    0       0    0.0
# 55               Puffed Wheat   Q    C        50        2    0       0    1.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 3     8.0       0     330        25      3    1.00  0.50  93.704912
# 20   21.0       0      -1         0      2    1.00  1.00  64.533816
# 54   13.0       0      15         0      3    0.50  1.00  60.756112
# 55   10.0       0      50         0      3    0.50  1.00  63.005645
# ...

# %% [markdown]
# using numpy and pandas now we will calculate the mean median and mode for some columns

# %%
import numpy as np

val=np.mean(df['calories'])
val1=np.median(df['sugars'])
val2=df['protein'].mode()
val , val1 , val2
# Out:
# (np.float64(106.88311688311688),
#  np.float64(7.0),
#  0    3
#  Name: protein, dtype: int64)

# %% [markdown]
# Finding minimum and maximum rating of cereals using pandas

# %%
df[df['rating'] == df['rating'].max()]
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 3    8.0       0     330        25      3     1.0   0.5  93.704912

# %%
df[df['rating'] == df['rating'].min()]
# Out:
#             name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 10  Cap'n'Crunch   Q    C       120        1    2     220    0.0   12.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 10      12      35        25      2     1.0  0.75  18.042851

# %% [markdown]
# Now we need to check the total calories consumed by hot and cold type

# %%
df['calories'].groupby([df['type']]).mean()
# Out:
# type
# C    107.162162
# H    100.000000
# Name: calories, dtype: float64

# %% [markdown]
# We used Matplotlib to create a histogram — a special kind of graph that shows how many cereals fall into different calorie ranges.
# We divided the range of calories into 20 bins (small groups), so we could see exactly where most cereals are.
# The X-axis shows the number of calories.
# The Y-axis shows how many cereals fall into each calorie group

# %%
import matplotlib.pyplot as plt

df['calories'].hist(bins=20)
plt.title('Calories Distribution')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# We created a scatter plot (each point represents one cereal).
# X-axis: Amount of sugar (per each cereal).
# Y-axis: Rating (of each cereal).
# Each point shows a cereal’s sugar content and how was its rating
#
# The result of this visualization is  : The more sugar a cereal had, the lower its rating tended to be.

# %%
plt.scatter(df['sugars'], df['rating'])
plt.xlabel('Sugars')
plt.ylabel('Rating')
plt.title('Sugars vs Rating')
plt.show()

# %% [markdown]
# We used groupby() to group cereals by manufacturer (like Kellogg's, General Mills, Quaker, etc.).
# For each group, we calculated the mean (average) rating.
# Then, we plotted this as a bar chart — where each bar represents a manufacturer’s average cereal rating.

# %% [markdown]
# The result of this visualization:
#
# Some brands like Kellogg’s (K) and General Mills (G) stood tall — showing strong average ratings across multiple cereals.
# Others had lower average ratings, possibly due to producing more sugary, less healthy cereals.

# %%
df.groupby('mfr')['rating'].mean().plot(kind='bar')
plt.title('Average Rating by Manufacturer')
plt.ylabel('Rating')
plt.show()
