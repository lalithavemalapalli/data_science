# %%
# !cat examples/data 2.csv
# Out:
# cat: examples/data: No such file or directory
# cat: 2.csv: No such file or directory

# %%
import pandas as pd

# %%
df=pd.read_csv("data2.csv",sep=None,header=None)
# Out:
# /var/folders/2k/szdhz6bx58d6z_hbxdm_sn6m0000gn/T/ipykernel_21662/1849558959.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support sep=None with delim_whitespace=False; you can avoid this warning by specifying engine='python'.
#   df=pd.read_csv("data2.csv",sep=None,header=None)

# %%
df
# Out:
#                    0                 1                  2       3   \
# 0     ﻿Marital status  Application mode  Application order  Course
# 1                   1                17                  5     171
# 2                   1                15                  1    9254
# 3                   1                 1                  5    9070
# 4                   1                17                  2    9773
# ...               ...               ...                ...     ...
# 4420                1                 1                  6    9773
# 4421                1                 1                  2    9773
# 4422                1                 1                  1    9500
# 4423                1                 1                  1    9147
# 4424                1                10                  1    9773
#
#                                 4                       5   \
# 0     Daytime/evening attendance\t  Previous qualification
# ...

# %%
# ?pd.read__csv
# Out:
# Object `pd.read__csv` not found.

# %% [markdown]
# #### Numerical values

# %%
col1 = range(1,5)

# %%
col2 = range(6,10)

# %%
import numpy as np

# %%
col3 = np.random.rand(4)

# %%
col4 = np.random.rand(4)

# %%
col5 = np.random.normal(size=4)

# %%
import pandas as pd

# %%
col6= pd.Series(["a","b","c","d"], dtype="category")

# %%
col7=np.array([0,1,0,1])

# %%
dict={"col":col1,
      "col1":col2,
      "col2":col3,
      "col3":col4,
      "col4":col5,
      "col5":col6,
      "col6":col7}

# %%
df=pd.DataFrame(dict)

# %%
df
# Out:
#    col  col1      col2      col3      col4 col5  col6
# 0    1     6  0.555682  0.108930 -0.618503    a     0
# 1    2     7  0.303054  0.502101 -0.803239    b     1
# 2    3     8  0.591029  0.799014 -1.213111    c     0
# 3    4     9  0.609926  0.417135 -0.168332    d     1

# %%
df.head()
# Out:
#    col  col1      col2      col3      col4 col5  col6
# 0    1     6  0.555682  0.108930 -0.618503    a     0
# 1    2     7  0.303054  0.502101 -0.803239    b     1
# 2    3     8  0.591029  0.799014 -1.213111    c     0
# 3    4     9  0.609926  0.417135 -0.168332    d     1
