# %% [markdown]
# # SQL Assignment: Data Summarization and Transformation
#
# ## Overview
#
# In this assignment, you will apply SQL techniques to summarize and transform a sales dataset. You will write SQL queries to perform grouping, aggregation, and data transformation operations inspired by the "split-apply-combine" paradigm. The dataset you will work with is based on a CSV file (`sales_data.csv`) that has been imported into a SQL table named `sales_data` with the following columns:
#
# - **Date**: Date of the transaction.
# - **Store**: Store identifier.
# - **Product**: Product name or ID.
# - **Sales**: Revenue generated from the sale.
# - **Quantity**: Number of items sold.

# %% [markdown]
# ## Tasks
#
# ## Task 1: Basic Grouping and Aggregation
#
# - **Objective**: Group the data by `Store` and `Product` and compute summary statistics.
# - **Instructions**:

# %% [markdown]
# 1. Write a SQL query that groups the data by `Store` and `Product`.
#
# Solution :
#
# Here the task is to group the data by Store and product columns
# - for this task in sql first we need to select using the `select` command
# - And then group this data by store and product using the sql `groupby` command

# %%
import mysql.connector

# %%
MYSQL_HOST = "localhost"
MYSQL_USER = "root"

# %%
DATABASE_NAME = "sales_db"
TABLE_NAME = "sales_data"

# %%
conn = mysql.connector.connect(
    host=MYSQL_HOST,
    user=MYSQL_USER,
    database=DATABASE_NAME
)
cursor = conn.cursor()
cursor.execute("""SELECT Product
               FROM sales_data
               GROUP BY Product,Store;""")
result=cursor.fetchall()
for x in result:
    print(x)
conn.close()
# Out:
# ('Product 8',)
# ('Product 6',)
# ('Product 4',)
# ('Product 5',)
# ('Product 5',)
# ('Product 1',)
# ('Product 4',)
# ('Product 9',)
# ('Product 3',)
# ('Product 5',)
# ('Product 4',)
# ('Product 3',)
# ('Product 3',)
# ('Product 7',)
# ('Product 7',)
# ('Product 6',)
# ('Product 2',)
# ('Product 8',)
# ('Product 10',)
# ('Product 7',)
# ('Product 9',)
# ('Product 3',)
# ('Product 2',)
# ('Product 6',)
# ('Product 1',)
# ('Product 3',)
# ('Product 8',)
# ('Product 1',)
# ('Product 10',)
# ('Product 1',)
# ('Product 6',)
# ('Product 4',)
# ('Product 10',)
# ('Product 8',)
# ('Product 10',)
# ('Product 9',)
# ('Product 7',)
# ('Product 9',)
# ('Product 2',)
# ('Product 6',)
# ('Product 7',)
# ('Product 1',)
# ('Product 9',)
# ('Product 4',)
# ('Product 8',)
# ('Product 2',)
# ('Product 5',)
# ('Product 2',)
# ('Product 10',)
# ('Product 5',)

# %% [markdown]
# 2. For each group, calculate:
#      - **Total Sales**: Sum of the `Sales` column.
#      - **Average Quantity Sold**: Average of the `Quantity` column.
#      - **Transaction Count**: The number of transactions (i.e., count of rows).
#   3. Return the results in a table with columns for `Store`, `Product`, `Total_Sales`, `Avg_Quantity`, and `Transaction_Count`.
#
# Solution :
#
# Here the task is to calculate te total sales , average quantity sold , total transation and returning the results in the table with columns Store , product , total sales , avg_quantity and transactio_count .
# - for this we need to select the columns using the `select` command of the sql
# - to calculate the total sales we use the `sum` command of the sql
# - to calculate the average quantity sold we use the `avg` comand of the sql
# - to calculate the total transaction we use the `count` command of the sql

# %%
conn = mysql.connector.connect(
    host=MYSQL_HOST,
    user=MYSQL_USER,
    database=DATABASE_NAME
)
cursor = conn.cursor()
cursor.execute("""SELECT Store, Product,
  SUM(Sales) AS Total_Sales,
  AVG(Quantity) AS Avg_Quantity,
  COUNT(*) AS Transaction_Count
FROM sales_data
GROUP BY Store, Product;
""")
result=cursor.fetchall()
for x in result:
    print(x)
conn.close()
# Out:
# ('Store D', 'Product 8', Decimal('6892.04'), Decimal('6.0000'), 19)
# ('Store B', 'Product 6', Decimal('6568.42'), Decimal('5.6250'), 24)
# ('Store E', 'Product 4', Decimal('8180.80'), Decimal('5.4400'), 25)
# ('Store A', 'Product 5', Decimal('7729.20'), Decimal('5.8400'), 25)
# ('Store E', 'Product 5', Decimal('8545.16'), Decimal('5.1538'), 26)
# ('Store D', 'Product 1', Decimal('5684.21'), Decimal('5.9375'), 16)
# ('Store C', 'Product 4', Decimal('8038.50'), Decimal('5.6923'), 26)
# ('Store C', 'Product 9', Decimal('6684.95'), Decimal('5.5238'), 21)
# ('Store A', 'Product 3', Decimal('6720.01'), Decimal('6.4091'), 22)
# ('Store C', 'Product 5', Decimal('4697.12'), Decimal('6.7857'), 14)
# ('Store B', 'Product 4', Decimal('8480.77'), Decimal('4.8966'), 29)
# ('Store D', 'Product 3', Decimal('6241.96'), Decimal('5.8182'), 22)
# ('Store C', 'Product 3', Decimal('4948.81'), Decimal('5.1500'), 20)
# ('Store B', 'Product 7', Decimal('5259.88'), Decimal('4.6111'), 18)
# ('Store A', 'Product 7', Decimal('5394.99'), Decimal('4.5000'), 24)
# ('Store E', 'Product 6', Decimal('5437.28'), Decimal('4.6957'), 23)
# ('Store A', 'Product 2', Decimal('6865.40'), Decimal('4.8750'), 24)
# ('Store A', 'Product 8', Decimal('5733.97'), Decimal('5.5500'), 20)
# ('Store C', 'Product 10', Decimal('4531.28'), Decimal('5.1765'), 17)
# ('Store D', 'Product 7', Decimal('4264.62'), Decimal('5.6429'), 14)
# ('Store B', 'Product 9', Decimal('3911.83'), Decimal('4.4737'), 19)
# ('Store B', 'Product 3', Decimal('4636.64'), Decimal('5.3750'), 16)
# ('Store C', 'Product 2', Decimal('5757.30'), Decimal('5.0500'), 20)
# ('Store A', 'Product 6', Decimal('4472.30'), Decimal('6.4000'), 15)
# ('Store B', 'Product 1', Decimal('5417.12'), Decimal('4.9444'), 18)
# ('Store E', 'Product 3', Decimal('6511.09'), Decimal('5.1667'), 24)
# ('Store C', 'Product 8', Decimal('7736.36'), Decimal('5.7826'), 23)
# ('Store A', 'Product 1', Decimal('4215.80'), Decimal('5.1333'), 15)
# ('Store E', 'Product 10', Decimal('5991.07'), Decimal('5.7391'), 23)
# ('Store C', 'Product 1', Decimal('4883.85'), Decimal('4.5556'), 18)
# ('Store C', 'Product 6', Decimal('5461.22'), Decimal('5.1111'), 18)
# ('Store A', 'Product 4', Decimal('6282.59'), Decimal('5.3478'), 23)
# ('Store A', 'Product 10', Decimal('5962.39'), Decimal('5.9412'), 17)
# ('Store B', 'Product 8', Decimal('5703.23'), Decimal('5.2778'), 18)
# ('Store B', 'Product 10', Decimal('5104.69'), Decimal('5.6471'), 17)
# ('Store D', 'Product 9', Decimal('6390.47'), Decimal('5.4000'), 25)
# ('Store C', 'Product 7', Decimal('4186.06'), Decimal('5.7368'), 19)
# ('Store E', 'Product 9', Decimal('3089.77'), Decimal('4.7143'), 14)
# ('Store D', 'Product 2', Decimal('4446.71'), Decimal('5.9474'), 19)
# ('Store D', 'Product 6', Decimal('3184.58'), Decimal('5.1053'), 19)
# ('Store E', 'Product 7', Decimal('5824.53'), Decimal('5.6000'), 20)
# ('Store E', 'Product 1', Decimal('5463.62'), Decimal('5.2105'), 19)
# ('Store A', 'Product 9', Decimal('5139.31'), Decimal('4.2609'), 23)
# ('Store D', 'Product 4', Decimal('4345.45'), Decimal('6.0833'), 12)
# ('Store E', 'Product 8', Decimal('5507.05'), Decimal('4.8500'), 20)
# ('Store E', 'Product 2', Decimal('3287.87'), Decimal('6.0000'), 12)
# ('Store D', 'Product 5', Decimal('6274.37'), Decimal('5.2381'), 21)
# ('Store B', 'Product 2', Decimal('5873.91'), Decimal('6.6000'), 20)
# ('Store D', 'Product 10', Decimal('6353.06'), Decimal('5.7895'), 19)
# ('Store B', 'Product 5', Decimal('6038.92'), Decimal('5.0800'), 25)

# %% [markdown]
# ## Task 2: Multiple Aggregations
#
# - **Objective**: Apply several aggregation functions to each group.
# - **Instructions**:

# %% [markdown]
# 1. Using the same grouping by `Store` and `Product`, write a SQL query to calculate:
#      - **Total Sales**
#      - **Mean Sales**
#      - **Standard Deviation of Sales** (use `STDDEV` or an equivalent function available in your SQL dialect)
#      - **Total Quantity Sold**
#   2. Ensure that each aggregated column is clearly labeled (e.g., `Mean_Sales`, `StdDev_Sales`, `Total_Quantity`).
#
# Solution :
#
# Here the task is to caluclate the total sales, mean sales , standard deviation of sales and total quantity sold using the diffrent sql command and name all those columnsa s total_sales , mean_sales,stdDev_sales,total_quantity
# - To calculate the total_sales we use the `sum()` method of the sql
# - To calulate the Mean_sales we use the `avg()` method of the sql
# - to calculate the standard deviation of the sales we use the `stddev()` methos of the sql
# - To calculate the Total quantity sold we use the `sum()` method from the sql

# %%
conn = mysql.connector.connect(
    host=MYSQL_HOST,
    user=MYSQL_USER,
    database=DATABASE_NAME
)
cursor = conn.cursor()
cursor.execute("""SELECT Store, Product,
  SUM(Sales) AS Total_Sales,
  AVG(Sales) AS Mean_Sales,
  STDDEV(Sales) AS StdDev_Sales,
  SUM(Quantity) AS Total_Quantity
FROM sales_data
GROUP BY Store, Product;""")
result=cursor.fetchall()
for x in result:
    print(x)
conn.close()
# Out:
# ('Store D', 'Product 8', Decimal('6892.04'), Decimal('362.738947'), 311.51716630734035, Decimal('114'))
# ('Store B', 'Product 6', Decimal('6568.42'), Decimal('273.684167'), 172.936167195603, Decimal('135'))
# ('Store E', 'Product 4', Decimal('8180.80'), Decimal('327.232000'), 313.0020270477493, Decimal('136'))
# ('Store A', 'Product 5', Decimal('7729.20'), Decimal('309.168000'), 307.7792195974251, Decimal('146'))
# ('Store E', 'Product 5', Decimal('8545.16'), Decimal('328.660000'), 203.4786097433264, Decimal('134'))
# ('Store D', 'Product 1', Decimal('5684.21'), Decimal('355.263125'), 242.17958194072506, Decimal('95'))
# ('Store C', 'Product 4', Decimal('8038.50'), Decimal('309.173077'), 236.45066726924458, Decimal('148'))
# ('Store C', 'Product 9', Decimal('6684.95'), Decimal('318.330952'), 188.78277688049835, Decimal('116'))
# ('Store A', 'Product 3', Decimal('6720.01'), Decimal('305.455000'), 219.07947571496845, Decimal('141'))
# ('Store C', 'Product 5', Decimal('4697.12'), Decimal('335.508571'), 283.2389610219899, Decimal('95'))
# ('Store B', 'Product 4', Decimal('8480.77'), Decimal('292.440345'), 220.68820108895966, Decimal('142'))
# ('Store D', 'Product 3', Decimal('6241.96'), Decimal('283.725455'), 229.91233745865506, Decimal('128'))
# ('Store C', 'Product 3', Decimal('4948.81'), Decimal('247.440500'), 247.94372358410286, Decimal('103'))
# ('Store B', 'Product 7', Decimal('5259.88'), Decimal('292.215556'), 180.97862167247584, Decimal('83'))
# ('Store A', 'Product 7', Decimal('5394.99'), Decimal('224.791250'), 193.53737634955897, Decimal('108'))
# ('Store E', 'Product 6', Decimal('5437.28'), Decimal('236.403478'), 228.3827497789563, Decimal('108'))
# ('Store A', 'Product 2', Decimal('6865.40'), Decimal('286.058333'), 237.96051965376293, Decimal('117'))
# ('Store A', 'Product 8', Decimal('5733.97'), Decimal('286.698500'), 213.73239086004256, Decimal('111'))
# ('Store C', 'Product 10', Decimal('4531.28'), Decimal('266.545882'), 271.80895230590403, Decimal('88'))
# ('Store D', 'Product 7', Decimal('4264.62'), Decimal('304.615714'), 210.1909043062074, Decimal('79'))
# ('Store B', 'Product 9', Decimal('3911.83'), Decimal('205.885789'), 204.05465545742987, Decimal('85'))
# ('Store B', 'Product 3', Decimal('4636.64'), Decimal('289.790000'), 241.27440125301314, Decimal('86'))
# ('Store C', 'Product 2', Decimal('5757.30'), Decimal('287.865000'), 203.19884946770736, Decimal('101'))
# ('Store A', 'Product 6', Decimal('4472.30'), Decimal('298.153333'), 229.42334506806895, Decimal('96'))
# ('Store B', 'Product 1', Decimal('5417.12'), Decimal('300.951111'), 267.1324010442282, Decimal('89'))
# ('Store E', 'Product 3', Decimal('6511.09'), Decimal('271.295417'), 164.86511638253373, Decimal('124'))
# ('Store C', 'Product 8', Decimal('7736.36'), Decimal('336.363478'), 253.43373981152988, Decimal('133'))
# ('Store A', 'Product 1', Decimal('4215.80'), Decimal('281.053333'), 250.71722428974746, Decimal('77'))
# ('Store E', 'Product 10', Decimal('5991.07'), Decimal('260.481304'), 238.6810468296341, Decimal('132'))
# ('Store C', 'Product 1', Decimal('4883.85'), Decimal('271.325000'), 229.2065616970858, Decimal('82'))
# ('Store C', 'Product 6', Decimal('5461.22'), Decimal('303.401111'), 264.05447819402906, Decimal('92'))
# ('Store A', 'Product 4', Decimal('6282.59'), Decimal('273.156087'), 233.54794669709094, Decimal('123'))
# ('Store A', 'Product 10', Decimal('5962.39'), Decimal('350.728824'), 266.4687705326914, Decimal('101'))
# ('Store B', 'Product 8', Decimal('5703.23'), Decimal('316.846111'), 196.948003124877, Decimal('95'))
# ('Store B', 'Product 10', Decimal('5104.69'), Decimal('300.275882'), 196.9760861884097, Decimal('96'))
# ('Store D', 'Product 9', Decimal('6390.47'), Decimal('255.618800'), 247.55937549315314, Decimal('135'))
# ('Store C', 'Product 7', Decimal('4186.06'), Decimal('220.318947'), 187.29987208512046, Decimal('109'))
# ('Store E', 'Product 9', Decimal('3089.77'), Decimal('220.697857'), 225.19198083218342, Decimal('66'))
# ('Store D', 'Product 2', Decimal('4446.71'), Decimal('234.037368'), 165.50914459843713, Decimal('113'))
# ('Store D', 'Product 6', Decimal('3184.58'), Decimal('167.609474'), 137.4133522384459, Decimal('97'))
# ('Store E', 'Product 7', Decimal('5824.53'), Decimal('291.226500'), 167.46359969482924, Decimal('112'))
# ('Store E', 'Product 1', Decimal('5463.62'), Decimal('287.558947'), 179.229599261739, Decimal('99'))
# ('Store A', 'Product 9', Decimal('5139.31'), Decimal('223.448261'), 181.8197225790276, Decimal('98'))
# ('Store D', 'Product 4', Decimal('4345.45'), Decimal('362.120833'), 227.10682337680998, Decimal('73'))
# ('Store E', 'Product 8', Decimal('5507.05'), Decimal('275.352500'), 219.46462295493095, Decimal('97'))
# ('Store E', 'Product 2', Decimal('3287.87'), Decimal('273.989167'), 219.92473900019874, Decimal('72'))
# ('Store D', 'Product 5', Decimal('6274.37'), Decimal('298.779524'), 257.83403184212074, Decimal('110'))
# ('Store B', 'Product 2', Decimal('5873.91'), Decimal('293.695500'), 189.17075998882595, Decimal('132'))
# ('Store D', 'Product 10', Decimal('6353.06'), Decimal('334.371579'), 247.12084962333623, Decimal('110'))
# ('Store B', 'Product 5', Decimal('6038.92'), Decimal('241.556800'), 169.88603798358474, Decimal('127'))

# %% [markdown]
# ## Task 3: Custom Aggregation - Sales per Transaction Ratio
#
# - **Objective**: Compute a custom metric for each group.
# - **Instructions**:

# %% [markdown]
# 1. Write a SQL query that calculates the **Sales per Transaction** ratio for each group by dividing the total sales by the number of transactions.
# 2. Display the results with the columns: `Store`, `Product`, and `Sales_Per_Transaction`.
#
# Solution:
# Here the task is to calculate the sales per transaction ratio for each group by dividing the total sales by the number of transactions and we need to display the result with the colums Store ,product m sales_per_transaction
# - For this first we need to select the columns Store and Product using the `select` statment of the sql
# - And then we need to calculate the total sales by usiing the `sum()` function
# - and then we need to calculate the number of transactions by `count()` function
# - lastly we need to divide the total sales and number of transaction and give the column name using the `AS` keyword as sales_per_transaction

# %%
conn = mysql.connector.connect(
    host=MYSQL_HOST,
    user=MYSQL_USER,
    database=DATABASE_NAME
)
cursor = conn.cursor()
cursor.execute("""SELECT Store, Product,
  SUM(Sales) / COUNT(*) AS Sales_Per_Transaction
FROM sales_data
GROUP BY Store, Product;
""")
result=cursor.fetchall()
for x in result:
    print(x)
conn.close()
# Out:
# ('Store D', 'Product 8', Decimal('362.738947'))
# ('Store B', 'Product 6', Decimal('273.684167'))
# ('Store E', 'Product 4', Decimal('327.232000'))
# ('Store A', 'Product 5', Decimal('309.168000'))
# ('Store E', 'Product 5', Decimal('328.660000'))
# ('Store D', 'Product 1', Decimal('355.263125'))
# ('Store C', 'Product 4', Decimal('309.173077'))
# ('Store C', 'Product 9', Decimal('318.330952'))
# ('Store A', 'Product 3', Decimal('305.455000'))
# ('Store C', 'Product 5', Decimal('335.508571'))
# ('Store B', 'Product 4', Decimal('292.440345'))
# ('Store D', 'Product 3', Decimal('283.725455'))
# ('Store C', 'Product 3', Decimal('247.440500'))
# ('Store B', 'Product 7', Decimal('292.215556'))
# ('Store A', 'Product 7', Decimal('224.791250'))
# ('Store E', 'Product 6', Decimal('236.403478'))
# ('Store A', 'Product 2', Decimal('286.058333'))
# ('Store A', 'Product 8', Decimal('286.698500'))
# ('Store C', 'Product 10', Decimal('266.545882'))
# ('Store D', 'Product 7', Decimal('304.615714'))
# ('Store B', 'Product 9', Decimal('205.885789'))
# ('Store B', 'Product 3', Decimal('289.790000'))
# ('Store C', 'Product 2', Decimal('287.865000'))
# ('Store A', 'Product 6', Decimal('298.153333'))
# ('Store B', 'Product 1', Decimal('300.951111'))
# ('Store E', 'Product 3', Decimal('271.295417'))
# ('Store C', 'Product 8', Decimal('336.363478'))
# ('Store A', 'Product 1', Decimal('281.053333'))
# ('Store E', 'Product 10', Decimal('260.481304'))
# ('Store C', 'Product 1', Decimal('271.325000'))
# ('Store C', 'Product 6', Decimal('303.401111'))
# ('Store A', 'Product 4', Decimal('273.156087'))
# ('Store A', 'Product 10', Decimal('350.728824'))
# ('Store B', 'Product 8', Decimal('316.846111'))
# ('Store B', 'Product 10', Decimal('300.275882'))
# ('Store D', 'Product 9', Decimal('255.618800'))
# ('Store C', 'Product 7', Decimal('220.318947'))
# ('Store E', 'Product 9', Decimal('220.697857'))
# ('Store D', 'Product 2', Decimal('234.037368'))
# ('Store D', 'Product 6', Decimal('167.609474'))
# ('Store E', 'Product 7', Decimal('291.226500'))
# ('Store E', 'Product 1', Decimal('287.558947'))
# ('Store A', 'Product 9', Decimal('223.448261'))
# ('Store D', 'Product 4', Decimal('362.120833'))
# ('Store E', 'Product 8', Decimal('275.352500'))
# ('Store E', 'Product 2', Decimal('273.989167'))
# ('Store D', 'Product 5', Decimal('298.779524'))
# ('Store B', 'Product 2', Decimal('293.695500'))
# ('Store D', 'Product 10', Decimal('334.371579'))
# ('Store B', 'Product 5', Decimal('241.556800'))

# %% [markdown]
# ### Task 4: Data Transformation with Window Functions
#
# - **Objective**: Broadcast group-level statistics back to each row.
# - **Instructions**:

# %% [markdown]
# 1. Write a SQL query that uses window functions to compute the average `Sales` for each `Store` and include this average as a new column for every row.
#   2. Additionally, add another column that shows the difference between the individual `Sales` value and the store's average `Sales`.
#   3. Return the result with columns: `Date`, `Store`, `Product`, `Sales`, `Store_Avg_Sales`, and `Sales_Difference`.
#
# Solution :
# Here the task is to calculate the average sales per store as Store_avg_sales and difference between the individual sales value and the stores_avg value using the window function
# - Basically window function in sql means in the group of rows we need to apply our caluclations to the some part of the rows those some part of the rows is considered as the window function
#   * in this window functuon we are having `over` and `pertition by` functions
#      - this `over` function is used to apply our calculations over some group
#      - this `partition by ` function is used to partition the group by some value
# - So here we are partitioning the store group by sales_avg
# - and we are applying the sales avg over the partitioned Store
# - And we are nameing the stores avg sales as `Store_Avg_Sales`
# - And diffrence between individual sales and sotes sales avg  as `Sales_Difference`

# %%
conn = mysql.connector.connect(
    host=MYSQL_HOST,
    user=MYSQL_USER,
    database=DATABASE_NAME
)
cursor = conn.cursor()
cursor.execute("""SELECT Date, Store, Product, Sales,
  AVG(Sales) OVER (PARTITION BY Store) AS Store_Avg_Sales,
  Sales - AVG(Sales) OVER (PARTITION BY Store) AS Sales_Difference
FROM sales_data;
""")
result=cursor.fetchall()
for x in result:
    print(x)
conn.close()
# Out:
# (datetime.date(2023, 5, 26), 'Store A', 'Product 2', Decimal('180.69'), Decimal('281.326731'), Decimal('-100.636731'))
# (datetime.date(2023, 4, 24), 'Store A', 'Product 9', Decimal('189.28'), Decimal('281.326731'), Decimal('-92.046731'))
# (datetime.date(2023, 8, 8), 'Store A', 'Product 1', Decimal('49.17'), Decimal('281.326731'), Decimal('-232.156731'))
# (datetime.date(2023, 8, 12), 'Store A', 'Product 5', Decimal('766.17'), Decimal('281.326731'), Decimal('484.843269'))
# (datetime.date(2023, 1, 1), 'Store A', 'Product 5', Decimal('109.13'), Decimal('281.326731'), Decimal('-172.196731'))
# (datetime.date(2023, 8, 6), 'Store A', 'Product 1', Decimal('92.52'), Decimal('281.326731'), Decimal('-188.806731'))
# (datetime.date(2023, 8, 5), 'Store A', 'Product 2', Decimal('196.31'), Decimal('281.326731'), Decimal('-85.016731'))
# (datetime.date(2023, 8, 3), 'Store A', 'Product 10', Decimal('187.21'), Decimal('281.326731'), Decimal('-94.116731'))
# (datetime.date(2023, 7, 31), 'Store A', 'Product 9', Decimal('124.59'), Decimal('281.326731'), Decimal('-156.736731'))
# (datetime.date(2023, 1, 3), 'Store A', 'Product 5', Decimal('72.52'), Decimal('281.326731'), Decimal('-208.806731'))
# (datetime.date(2023, 7, 31), 'Store A', 'Product 9', Decimal('167.88'), Decimal('281.326731'), Decimal('-113.446731'))
# (datetime.date(2023, 1, 4), 'Store A', 'Product 3', Decimal('144.23'), Decimal('281.326731'), Decimal('-137.096731'))
# (datetime.date(2023, 7, 27), 'Store A', 'Product 5', Decimal('687.60'), Decimal('281.326731'), Decimal('406.273269'))
# (datetime.date(2023, 7, 27), 'Store A', 'Product 7', Decimal('25.42'), Decimal('281.326731'), Decimal('-255.906731'))
# (datetime.date(2023, 12, 26), 'Store A', 'Product 2', Decimal('78.48'), Decimal('281.326731'), Decimal('-202.846731'))
# (datetime.date(2023, 7, 26), 'Store A', 'Product 3', Decimal('251.14'), Decimal('281.326731'), Decimal('-30.186731'))
# (datetime.date(2023, 7, 26), 'Store A', 'Product 9', Decimal('56.91'), Decimal('281.326731'), Decimal('-224.416731'))
# (datetime.date(2023, 1, 5), 'Store A', 'Product 7', Decimal('172.48'), Decimal('281.326731'), Decimal('-108.846731'))
# (datetime.date(2023, 12, 25), 'Store A', 'Product 7', Decimal('77.81'), Decimal('281.326731'), Decimal('-203.516731'))
# (datetime.date(2023, 1, 6), 'Store A', 'Product 2', Decimal('187.95'), Decimal('281.326731'), Decimal('-93.376731'))
# (datetime.date(2023, 1, 6), 'Store A', 'Product 8', Decimal('333.41'), Decimal('281.326731'), Decimal('52.083269'))
# (datetime.date(2023, 8, 19), 'Store A', 'Product 4', Decimal('399.00'), Decimal('281.326731'), Decimal('117.673269'))
# (datetime.date(2023, 12, 24), 'Store A', 'Product 3', Decimal('132.62'), Decimal('281.326731'), Decimal('-148.706731'))
# (datetime.date(2023, 8, 21), 'Store A', 'Product 4', Decimal('20.97'), Decimal('281.326731'), Decimal('-260.356731'))
# (datetime.date(2023, 8, 21), 'Store A', 'Product 5', Decimal('28.72'), Decimal('281.326731'), Decimal('-252.606731'))
# (datetime.date(2023, 8, 21), 'Store A', 'Product 5', Decimal('877.00'), Decimal('281.326731'), Decimal('595.673269'))
# (datetime.date(2023, 8, 22), 'Store A', 'Product 4', Decimal('169.16'), Decimal('281.326731'), Decimal('-112.166731'))
# (datetime.date(2023, 8, 24), 'Store A', 'Product 9', Decimal('280.16'), Decimal('281.326731'), Decimal('-1.166731'))
# (datetime.date(2023, 7, 21), 'Store A', 'Product 6', Decimal('114.38'), Decimal('281.326731'), Decimal('-166.946731'))
# (datetime.date(2023, 7, 17), 'Store A', 'Product 7', Decimal('206.86'), Decimal('281.326731'), Decimal('-74.466731'))
# (datetime.date(2023, 1, 9), 'Store A', 'Product 6', Decimal('373.39'), Decimal('281.326731'), Decimal('92.063269'))
# (datetime.date(2023, 7, 17), 'Store A', 'Product 9', Decimal('168.86'), Decimal('281.326731'), Decimal('-112.466731'))
# (datetime.date(2023, 1, 10), 'Store A', 'Product 2', Decimal('21.89'), Decimal('281.326731'), Decimal('-259.436731'))
# (datetime.date(2023, 7, 16), 'Store A', 'Product 8', Decimal('29.62'), Decimal('281.326731'), Decimal('-251.706731'))
# (datetime.date(2023, 7, 15), 'Store A', 'Product 2', Decimal('464.59'), Decimal('281.326731'), Decimal('183.263269'))
# (datetime.date(2023, 8, 27), 'Store A', 'Product 6', Decimal('36.05'), Decimal('281.326731'), Decimal('-245.276731'))
# (datetime.date(2023, 1, 13), 'Store A', 'Product 1', Decimal('510.29'), Decimal('281.326731'), Decimal('228.963269'))
# (datetime.date(2023, 8, 27), 'Store A', 'Product 2', Decimal('698.16'), Decimal('281.326731'), Decimal('416.833269'))
# (datetime.date(2023, 7, 13), 'Store A', 'Product 9', Decimal('313.96'), Decimal('281.326731'), Decimal('32.633269'))
# (datetime.date(2023, 8, 30), 'Store A', 'Product 2', Decimal('263.73'), Decimal('281.326731'), Decimal('-17.596731'))
# (datetime.date(2023, 8, 30), 'Store A', 'Product 9', Decimal('102.98'), Decimal('281.326731'), Decimal('-178.346731'))
# (datetime.date(2023, 7, 9), 'Store A', 'Product 9', Decimal('445.31'), Decimal('281.326731'), Decimal('163.983269'))
# (datetime.date(2023, 1, 14), 'Store A', 'Product 7', Decimal('230.83'), Decimal('281.326731'), Decimal('-50.496731'))
# (datetime.date(2023, 7, 9), 'Store A', 'Product 7', Decimal('80.89'), Decimal('281.326731'), Decimal('-200.436731'))
# (datetime.date(2023, 8, 30), 'Store A', 'Product 8', Decimal('96.34'), Decimal('281.326731'), Decimal('-184.986731'))
# (datetime.date(2023, 9, 4), 'Store A', 'Product 9', Decimal('249.10'), Decimal('281.326731'), Decimal('-32.226731'))
# (datetime.date(2023, 9, 4), 'Store A', 'Product 9', Decimal('498.61'), Decimal('281.326731'), Decimal('217.283269'))
# (datetime.date(2023, 9, 6), 'Store A', 'Product 6', Decimal('600.35'), Decimal('281.326731'), Decimal('319.023269'))
# (datetime.date(2023, 7, 4), 'Store A', 'Product 5', Decimal('148.70'), Decimal('281.326731'), Decimal('-132.626731'))
# (datetime.date(2023, 12, 31), 'Store A', 'Product 9', Decimal('29.05'), Decimal('281.326731'), Decimal('-252.276731'))
# (datetime.date(2023, 1, 19), 'Store A', 'Product 4', Decimal('77.84'), Decimal('281.326731'), Decimal('-203.486731'))
# (datetime.date(2023, 12, 18), 'Store A', 'Product 4', Decimal('77.34'), Decimal('281.326731'), Decimal('-203.986731'))
# (datetime.date(2023, 12, 17), 'Store A', 'Product 6', Decimal('171.12'), Decimal('281.326731'), Decimal('-110.206731'))
# (datetime.date(2023, 9, 8), 'Store A', 'Product 4', Decimal('81.80'), Decimal('281.326731'), Decimal('-199.526731'))
# (datetime.date(2023, 1, 20), 'Store A', 'Product 10', Decimal('444.87'), Decimal('281.326731'), Decimal('163.543269'))
# (datetime.date(2023, 6, 29), 'Store A', 'Product 6', Decimal('102.56'), Decimal('281.326731'), Decimal('-178.766731'))
# (datetime.date(2023, 9, 10), 'Store A', 'Product 4', Decimal('317.19'), Decimal('281.326731'), Decimal('35.863269'))
# (datetime.date(2023, 6, 27), 'Store A', 'Product 10', Decimal('204.68'), Decimal('281.326731'), Decimal('-76.646731'))
# (datetime.date(2023, 9, 10), 'Store A', 'Product 6', Decimal('266.65'), Decimal('281.326731'), Decimal('-14.676731'))
# (datetime.date(2023, 6, 24), 'Store A', 'Product 4', Decimal('382.19'), Decimal('281.326731'), Decimal('100.863269'))
# (datetime.date(2023, 12, 16), 'Store A', 'Product 9', Decimal('394.23'), Decimal('281.326731'), Decimal('112.903269'))
# (datetime.date(2023, 9, 10), 'Store A', 'Product 9', Decimal('188.33'), Decimal('281.326731'), Decimal('-92.996731'))
# (datetime.date(2023, 9, 10), 'Store A', 'Product 10', Decimal('51.82'), Decimal('281.326731'), Decimal('-229.506731'))
# (datetime.date(2023, 6, 22), 'Store A', 'Product 2', Decimal('308.50'), Decimal('281.326731'), Decimal('27.173269'))
# (datetime.date(2023, 6, 19), 'Store A', 'Product 5', Decimal('43.77'), Decimal('281.326731'), Decimal('-237.556731'))
# (datetime.date(2023, 1, 26), 'Store A', 'Product 1', Decimal('12.72'), Decimal('281.326731'), Decimal('-268.606731'))
# (datetime.date(2023, 9, 16), 'Store A', 'Product 2', Decimal('872.70'), Decimal('281.326731'), Decimal('591.373269'))
# (datetime.date(2023, 9, 16), 'Store A', 'Product 5', Decimal('210.74'), Decimal('281.326731'), Decimal('-70.586731'))
# (datetime.date(2023, 6, 16), 'Store A', 'Product 4', Decimal('684.87'), Decimal('281.326731'), Decimal('403.543269'))
# (datetime.date(2023, 6, 15), 'Store A', 'Product 2', Decimal('610.82'), Decimal('281.326731'), Decimal('329.493269'))
# (datetime.date(2023, 6, 13), 'Store A', 'Product 5', Decimal('201.46'), Decimal('281.326731'), Decimal('-79.866731'))
# (datetime.date(2023, 12, 14), 'Store A', 'Product 10', Decimal('582.66'), Decimal('281.326731'), Decimal('301.333269'))
# (datetime.date(2023, 6, 13), 'Store A', 'Product 8', Decimal('309.09'), Decimal('281.326731'), Decimal('27.763269'))
# (datetime.date(2023, 1, 28), 'Store A', 'Product 3', Decimal('903.07'), Decimal('281.326731'), Decimal('621.743269'))
# (datetime.date(2023, 9, 21), 'Store A', 'Product 10', Decimal('118.00'), Decimal('281.326731'), Decimal('-163.326731'))
# (datetime.date(2023, 12, 14), 'Store A', 'Product 3', Decimal('55.89'), Decimal('281.326731'), Decimal('-225.436731'))
# (datetime.date(2023, 9, 21), 'Store A', 'Product 8', Decimal('655.52'), Decimal('281.326731'), Decimal('374.193269'))
# (datetime.date(2023, 1, 31), 'Store A', 'Product 9', Decimal('65.94'), Decimal('281.326731'), Decimal('-215.386731'))
# (datetime.date(2023, 2, 2), 'Store A', 'Product 3', Decimal('87.84'), Decimal('281.326731'), Decimal('-193.486731'))
# (datetime.date(2023, 12, 14), 'Store A', 'Product 10', Decimal('56.53'), Decimal('281.326731'), Decimal('-224.796731'))
# (datetime.date(2023, 6, 10), 'Store A', 'Product 4', Decimal('627.12'), Decimal('281.326731'), Decimal('345.793269'))
# (datetime.date(2023, 6, 10), 'Store A', 'Product 9', Decimal('91.24'), Decimal('281.326731'), Decimal('-190.086731'))
# (datetime.date(2023, 6, 9), 'Store A', 'Product 9', Decimal('181.36'), Decimal('281.326731'), Decimal('-99.966731'))
# (datetime.date(2023, 2, 3), 'Store A', 'Product 8', Decimal('156.50'), Decimal('281.326731'), Decimal('-124.826731'))
# (datetime.date(2023, 2, 3), 'Store A', 'Product 3', Decimal('184.17'), Decimal('281.326731'), Decimal('-97.156731'))
# (datetime.date(2023, 6, 7), 'Store A', 'Product 10', Decimal('57.95'), Decimal('281.326731'), Decimal('-223.376731'))
# (datetime.date(2023, 12, 12), 'Store A', 'Product 7', Decimal('304.99'), Decimal('281.326731'), Decimal('23.663269'))
# (datetime.date(2023, 6, 7), 'Store A', 'Product 5', Decimal('942.12'), Decimal('281.326731'), Decimal('660.793269'))
# (datetime.date(2023, 9, 25), 'Store A', 'Product 9', Decimal('112.94'), Decimal('281.326731'), Decimal('-168.386731'))
# (datetime.date(2023, 12, 12), 'Store A', 'Product 6', Decimal('339.30'), Decimal('281.326731'), Decimal('57.973269'))
# (datetime.date(2023, 9, 27), 'Store A', 'Product 6', Decimal('667.74'), Decimal('281.326731'), Decimal('386.413269'))
# (datetime.date(2023, 2, 5), 'Store A', 'Product 7', Decimal('80.23'), Decimal('281.326731'), Decimal('-201.096731'))
# (datetime.date(2023, 2, 5), 'Store A', 'Product 7', Decimal('676.81'), Decimal('281.326731'), Decimal('395.483269'))
# (datetime.date(2023, 9, 28), 'Store A', 'Product 1', Decimal('36.94'), Decimal('281.326731'), Decimal('-244.386731'))
# (datetime.date(2023, 2, 6), 'Store A', 'Product 5', Decimal('804.34'), Decimal('281.326731'), Decimal('523.013269'))
# (datetime.date(2023, 12, 10), 'Store A', 'Product 10', Decimal('617.78'), Decimal('281.326731'), Decimal('336.453269'))
# (datetime.date(2023, 6, 1), 'Store A', 'Product 4', Decimal('62.31'), Decimal('281.326731'), Decimal('-219.016731'))
# (datetime.date(2023, 6, 1), 'Store A', 'Product 10', Decimal('415.33'), Decimal('281.326731'), Decimal('134.003269'))
# (datetime.date(2023, 6, 1), 'Store A', 'Product 10', Decimal('389.28'), Decimal('281.326731'), Decimal('107.953269'))
# (datetime.date(2023, 2, 8), 'Store A', 'Product 3', Decimal('129.55'), Decimal('281.326731'), Decimal('-151.776731'))
# (datetime.date(2023, 9, 29), 'Store A', 'Product 8', Decimal('184.26'), Decimal('281.326731'), Decimal('-97.066731'))
# (datetime.date(2023, 5, 31), 'Store A', 'Product 6', Decimal('242.83'), Decimal('281.326731'), Decimal('-38.496731'))
# (datetime.date(2023, 5, 30), 'Store A', 'Product 2', Decimal('125.90'), Decimal('281.326731'), Decimal('-155.426731'))
# (datetime.date(2023, 12, 8), 'Store A', 'Product 8', Decimal('284.91'), Decimal('281.326731'), Decimal('3.583269'))
# (datetime.date(2023, 3, 21), 'Store A', 'Product 9', Decimal('94.13'), Decimal('281.326731'), Decimal('-187.196731'))
# (datetime.date(2023, 10, 5), 'Store A', 'Product 6', Decimal('687.94'), Decimal('281.326731'), Decimal('406.613269'))
# (datetime.date(2023, 2, 9), 'Store A', 'Product 8', Decimal('118.73'), Decimal('281.326731'), Decimal('-162.596731'))
# (datetime.date(2023, 12, 7), 'Store A', 'Product 10', Decimal('810.93'), Decimal('281.326731'), Decimal('529.603269'))
# (datetime.date(2023, 5, 25), 'Store A', 'Product 1', Decimal('38.72'), Decimal('281.326731'), Decimal('-242.606731'))
# (datetime.date(2023, 12, 6), 'Store A', 'Product 7', Decimal('12.94'), Decimal('281.326731'), Decimal('-268.386731'))
# (datetime.date(2023, 10, 6), 'Store A', 'Product 8', Decimal('533.43'), Decimal('281.326731'), Decimal('252.103269'))
# (datetime.date(2023, 10, 7), 'Store A', 'Product 3', Decimal('371.16'), Decimal('281.326731'), Decimal('89.833269'))
# (datetime.date(2023, 5, 24), 'Store A', 'Product 8', Decimal('156.81'), Decimal('281.326731'), Decimal('-124.516731'))
# (datetime.date(2023, 5, 23), 'Store A', 'Product 1', Decimal('140.50'), Decimal('281.326731'), Decimal('-140.826731'))
# (datetime.date(2023, 5, 23), 'Store A', 'Product 7', Decimal('387.87'), Decimal('281.326731'), Decimal('106.543269'))
# (datetime.date(2023, 5, 22), 'Store A', 'Product 1', Decimal('330.78'), Decimal('281.326731'), Decimal('49.453269'))
# (datetime.date(2023, 10, 9), 'Store A', 'Product 4', Decimal('870.71'), Decimal('281.326731'), Decimal('589.383269'))
# (datetime.date(2023, 2, 13), 'Store A', 'Product 9', Decimal('280.56'), Decimal('281.326731'), Decimal('-0.766731'))
# (datetime.date(2023, 12, 6), 'Store A', 'Product 7', Decimal('459.06'), Decimal('281.326731'), Decimal('177.733269'))
# (datetime.date(2023, 5, 18), 'Store A', 'Product 7', Decimal('175.54'), Decimal('281.326731'), Decimal('-105.786731'))
# (datetime.date(2023, 12, 5), 'Store A', 'Product 2', Decimal('155.56'), Decimal('281.326731'), Decimal('-125.766731'))
# (datetime.date(2023, 2, 15), 'Store A', 'Product 5', Decimal('59.44'), Decimal('281.326731'), Decimal('-221.886731'))
# (datetime.date(2023, 5, 17), 'Store A', 'Product 10', Decimal('288.56'), Decimal('281.326731'), Decimal('7.233269'))
# (datetime.date(2023, 2, 16), 'Store A', 'Product 9', Decimal('148.39'), Decimal('281.326731'), Decimal('-132.936731'))
# (datetime.date(2023, 2, 16), 'Store A', 'Product 7', Decimal('18.99'), Decimal('281.326731'), Decimal('-262.336731'))
# (datetime.date(2023, 12, 4), 'Store A', 'Product 8', Decimal('57.52'), Decimal('281.326731'), Decimal('-223.806731'))
# (datetime.date(2023, 10, 9), 'Store A', 'Product 5', Decimal('149.23'), Decimal('281.326731'), Decimal('-132.096731'))
# (datetime.date(2023, 2, 16), 'Store A', 'Product 5', Decimal('55.10'), Decimal('281.326731'), Decimal('-226.226731'))
# (datetime.date(2023, 10, 10), 'Store A', 'Product 4', Decimal('279.76'), Decimal('281.326731'), Decimal('-1.566731'))
# (datetime.date(2023, 10, 10), 'Store A', 'Product 2', Decimal('228.56'), Decimal('281.326731'), Decimal('-52.766731'))
# (datetime.date(2023, 2, 17), 'Store A', 'Product 7', Decimal('67.24'), Decimal('281.326731'), Decimal('-214.086731'))
# (datetime.date(2023, 10, 11), 'Store A', 'Product 6', Decimal('618.25'), Decimal('281.326731'), Decimal('336.923269'))
# (datetime.date(2023, 5, 14), 'Store A', 'Product 3', Decimal('166.63'), Decimal('281.326731'), Decimal('-114.696731'))
# (datetime.date(2023, 10, 11), 'Store A', 'Product 4', Decimal('701.71'), Decimal('281.326731'), Decimal('420.383269'))
# (datetime.date(2023, 2, 20), 'Store A', 'Product 5', Decimal('60.41'), Decimal('281.326731'), Decimal('-220.916731'))
# (datetime.date(2023, 10, 12), 'Store A', 'Product 3', Decimal('91.54'), Decimal('281.326731'), Decimal('-189.786731'))
# (datetime.date(2023, 5, 11), 'Store A', 'Product 8', Decimal('649.17'), Decimal('281.326731'), Decimal('367.843269'))
# (datetime.date(2023, 2, 20), 'Store A', 'Product 4', Decimal('208.24'), Decimal('281.326731'), Decimal('-73.086731'))
# (datetime.date(2023, 12, 2), 'Store A', 'Product 7', Decimal('74.75'), Decimal('281.326731'), Decimal('-206.576731'))
# (datetime.date(2023, 2, 20), 'Store A', 'Product 8', Decimal('339.52'), Decimal('281.326731'), Decimal('58.193269'))
# (datetime.date(2023, 5, 11), 'Store A', 'Product 2', Decimal('255.78'), Decimal('281.326731'), Decimal('-25.546731'))
# (datetime.date(2023, 2, 21), 'Store A', 'Product 1', Decimal('794.25'), Decimal('281.326731'), Decimal('512.923269'))
# (datetime.date(2023, 5, 10), 'Store A', 'Product 5', Decimal('179.32'), Decimal('281.326731'), Decimal('-102.006731'))
# (datetime.date(2023, 5, 8), 'Store A', 'Product 1', Decimal('717.05'), Decimal('281.326731'), Decimal('435.723269'))
# (datetime.date(2023, 5, 8), 'Store A', 'Product 4', Decimal('135.31'), Decimal('281.326731'), Decimal('-146.016731'))
# (datetime.date(2023, 2, 22), 'Store A', 'Product 2', Decimal('203.43'), Decimal('281.326731'), Decimal('-77.896731'))
# (datetime.date(2023, 10, 15), 'Store A', 'Product 4', Decimal('134.32'), Decimal('281.326731'), Decimal('-147.006731'))
# (datetime.date(2023, 12, 1), 'Store A', 'Product 5', Decimal('551.55'), Decimal('281.326731'), Decimal('270.223269'))
# (datetime.date(2023, 10, 16), 'Store A', 'Product 8', Decimal('42.48'), Decimal('281.326731'), Decimal('-238.846731'))
# (datetime.date(2023, 2, 22), 'Store A', 'Product 10', Decimal('189.79'), Decimal('281.326731'), Decimal('-91.536731'))
# (datetime.date(2023, 10, 19), 'Store A', 'Product 5', Decimal('33.84'), Decimal('281.326731'), Decimal('-247.486731'))
# (datetime.date(2023, 5, 3), 'Store A', 'Product 7', Decimal('400.99'), Decimal('281.326731'), Decimal('119.663269'))
# (datetime.date(2023, 5, 1), 'Store A', 'Product 3', Decimal('302.81'), Decimal('281.326731'), Decimal('21.483269'))
# (datetime.date(2023, 10, 28), 'Store A', 'Product 3', Decimal('253.49'), Decimal('281.326731'), Decimal('-27.836731'))
# (datetime.date(2023, 2, 23), 'Store A', 'Product 4', Decimal('352.51'), Decimal('281.326731'), Decimal('71.183269'))
# (datetime.date(2023, 4, 30), 'Store A', 'Product 4', Decimal('188.18'), Decimal('281.326731'), Decimal('-93.146731'))
# (datetime.date(2023, 11, 26), 'Store A', 'Product 7', Decimal('381.81'), Decimal('281.326731'), Decimal('100.483269'))
# (datetime.date(2023, 4, 29), 'Store A', 'Product 6', Decimal('59.53'), Decimal('281.326731'), Decimal('-221.796731'))
# (datetime.date(2023, 4, 28), 'Store A', 'Product 2', Decimal('779.77'), Decimal('281.326731'), Decimal('498.443269'))
# (datetime.date(2023, 4, 28), 'Store A', 'Product 1', Decimal('427.14'), Decimal('281.326731'), Decimal('145.813269'))
# (datetime.date(2023, 11, 26), 'Store A', 'Product 5', Decimal('154.86'), Decimal('281.326731'), Decimal('-126.466731'))
# (datetime.date(2023, 4, 27), 'Store A', 'Product 8', Decimal('95.26'), Decimal('281.326731'), Decimal('-186.066731'))
# (datetime.date(2023, 2, 27), 'Store A', 'Product 2', Decimal('17.36'), Decimal('281.326731'), Decimal('-263.966731'))
# (datetime.date(2023, 11, 23), 'Store A', 'Product 2', Decimal('373.80'), Decimal('281.326731'), Decimal('92.473269'))
# (datetime.date(2023, 11, 23), 'Store A', 'Product 3', Decimal('369.69'), Decimal('281.326731'), Decimal('88.363269'))
# (datetime.date(2023, 4, 26), 'Store A', 'Product 5', Decimal('22.78'), Decimal('281.326731'), Decimal('-258.546731'))
# (datetime.date(2023, 8, 10), 'Store A', 'Product 3', Decimal('338.48'), Decimal('281.326731'), Decimal('57.153269'))
# (datetime.date(2023, 8, 11), 'Store A', 'Product 10', Decimal('17.67'), Decimal('281.326731'), Decimal('-263.656731'))
# (datetime.date(2023, 4, 21), 'Store A', 'Product 4', Decimal('84.32'), Decimal('281.326731'), Decimal('-197.006731'))
# (datetime.date(2023, 4, 21), 'Store A', 'Product 2', Decimal('177.07'), Decimal('281.326731'), Decimal('-104.256731'))
# (datetime.date(2023, 11, 2), 'Store A', 'Product 2', Decimal('76.89'), Decimal('281.326731'), Decimal('-204.436731'))
# (datetime.date(2023, 4, 19), 'Store A', 'Product 5', Decimal('821.71'), Decimal('281.326731'), Decimal('540.383269'))
# (datetime.date(2023, 3, 3), 'Store A', 'Product 6', Decimal('82.81'), Decimal('281.326731'), Decimal('-198.516731'))
# (datetime.date(2023, 4, 18), 'Store A', 'Product 3', Decimal('190.12'), Decimal('281.326731'), Decimal('-91.206731'))
# (datetime.date(2023, 11, 21), 'Store A', 'Product 7', Decimal('88.84'), Decimal('281.326731'), Decimal('-192.486731'))
# (datetime.date(2023, 11, 3), 'Store A', 'Product 8', Decimal('457.50'), Decimal('281.326731'), Decimal('176.173269'))
# (datetime.date(2023, 4, 16), 'Store A', 'Product 2', Decimal('462.62'), Decimal('281.326731'), Decimal('181.293269'))
# (datetime.date(2023, 11, 6), 'Store A', 'Product 6', Decimal('109.40'), Decimal('281.326731'), Decimal('-171.926731'))
# (datetime.date(2023, 11, 6), 'Store A', 'Product 8', Decimal('139.25'), Decimal('281.326731'), Decimal('-142.076731'))
# (datetime.date(2023, 3, 4), 'Store A', 'Product 7', Decimal('360.41'), Decimal('281.326731'), Decimal('79.083269'))
# (datetime.date(2023, 4, 11), 'Store A', 'Product 3', Decimal('108.44'), Decimal('281.326731'), Decimal('-172.886731'))
# (datetime.date(2023, 4, 11), 'Store A', 'Product 3', Decimal('242.75'), Decimal('281.326731'), Decimal('-38.576731'))
# (datetime.date(2023, 3, 6), 'Store A', 'Product 1', Decimal('337.09'), Decimal('281.326731'), Decimal('55.763269'))
# (datetime.date(2023, 4, 10), 'Store A', 'Product 3', Decimal('580.06'), Decimal('281.326731'), Decimal('298.733269'))
# (datetime.date(2023, 3, 7), 'Store A', 'Product 10', Decimal('699.67'), Decimal('281.326731'), Decimal('418.343269'))
# (datetime.date(2023, 4, 9), 'Store A', 'Product 7', Decimal('8.08'), Decimal('281.326731'), Decimal('-273.246731'))
# (datetime.date(2023, 4, 9), 'Store A', 'Product 5', Decimal('325.14'), Decimal('281.326731'), Decimal('43.813269'))
# (datetime.date(2023, 11, 19), 'Store A', 'Product 5', Decimal('244.90'), Decimal('281.326731'), Decimal('-36.426731'))
# (datetime.date(2023, 3, 10), 'Store A', 'Product 7', Decimal('209.12'), Decimal('281.326731'), Decimal('-72.206731'))
# (datetime.date(2023, 11, 12), 'Store A', 'Product 8', Decimal('361.01'), Decimal('281.326731'), Decimal('79.683269'))
# (datetime.date(2023, 3, 10), 'Store A', 'Product 2', Decimal('82.61'), Decimal('281.326731'), Decimal('-198.716731'))
# (datetime.date(2023, 11, 12), 'Store A', 'Product 1', Decimal('29.58'), Decimal('281.326731'), Decimal('-251.746731'))
# (datetime.date(2023, 4, 5), 'Store A', 'Product 10', Decimal('829.66'), Decimal('281.326731'), Decimal('548.333269'))
# (datetime.date(2023, 3, 11), 'Store A', 'Product 8', Decimal('733.64'), Decimal('281.326731'), Decimal('452.313269'))
# (datetime.date(2023, 4, 4), 'Store A', 'Product 1', Decimal('487.21'), Decimal('281.326731'), Decimal('205.883269'))
# (datetime.date(2023, 4, 4), 'Store A', 'Product 5', Decimal('178.65'), Decimal('281.326731'), Decimal('-102.676731'))
# (datetime.date(2023, 4, 2), 'Store A', 'Product 7', Decimal('195.94'), Decimal('281.326731'), Decimal('-85.386731'))
# (datetime.date(2023, 3, 15), 'Store A', 'Product 4', Decimal('160.52'), Decimal('281.326731'), Decimal('-120.806731'))
# (datetime.date(2023, 11, 19), 'Store A', 'Product 4', Decimal('49.91'), Decimal('281.326731'), Decimal('-231.416731'))
# (datetime.date(2023, 4, 2), 'Store A', 'Product 7', Decimal('697.09'), Decimal('281.326731'), Decimal('415.763269'))
# (datetime.date(2023, 4, 2), 'Store A', 'Product 3', Decimal('563.28'), Decimal('281.326731'), Decimal('281.953269'))
# (datetime.date(2023, 11, 15), 'Store A', 'Product 1', Decimal('211.84'), Decimal('281.326731'), Decimal('-69.486731'))
# (datetime.date(2023, 3, 31), 'Store A', 'Product 3', Decimal('586.02'), Decimal('281.326731'), Decimal('304.693269'))
# (datetime.date(2023, 3, 30), 'Store A', 'Product 9', Decimal('855.02'), Decimal('281.326731'), Decimal('573.693269'))
# (datetime.date(2023, 11, 16), 'Store A', 'Product 4', Decimal('217.31'), Decimal('281.326731'), Decimal('-64.016731'))
# (datetime.date(2023, 11, 18), 'Store A', 'Product 3', Decimal('667.03'), Decimal('281.326731'), Decimal('385.703269'))
# (datetime.date(2023, 3, 23), 'Store A', 'Product 9', Decimal('100.48'), Decimal('281.326731'), Decimal('-180.846731'))
# (datetime.date(2023, 3, 22), 'Store A', 'Product 2', Decimal('42.23'), Decimal('281.326731'), Decimal('-239.096731'))
# (datetime.date(2023, 4, 24), 'Store B', 'Product 9', Decimal('69.43'), Decimal('279.389265'), Decimal('-209.959265'))
# (datetime.date(2023, 12, 8), 'Store B', 'Product 7', Decimal('490.80'), Decimal('279.389265'), Decimal('211.410735'))
# (datetime.date(2023, 1, 1), 'Store B', 'Product 6', Decimal('379.50'), Decimal('279.389265'), Decimal('100.110735'))
# (datetime.date(2023, 8, 12), 'Store B', 'Product 4', Decimal('50.05'), Decimal('279.389265'), Decimal('-229.339265'))
# (datetime.date(2023, 12, 31), 'Store B', 'Product 9', Decimal('67.57'), Decimal('279.389265'), Decimal('-211.819265'))
# (datetime.date(2023, 3, 19), 'Store B', 'Product 6', Decimal('70.09'), Decimal('279.389265'), Decimal('-209.299265'))
# (datetime.date(2023, 12, 31), 'Store B', 'Product 5', Decimal('235.00'), Decimal('279.389265'), Decimal('-44.389265'))
# (datetime.date(2023, 3, 24), 'Store B', 'Product 10', Decimal('459.67'), Decimal('279.389265'), Decimal('180.280735'))
# (datetime.date(2023, 3, 25), 'Store B', 'Product 4', Decimal('426.43'), Decimal('279.389265'), Decimal('147.040735'))
# (datetime.date(2023, 3, 26), 'Store B', 'Product 4', Decimal('29.35'), Decimal('279.389265'), Decimal('-250.039265'))
# (datetime.date(2023, 11, 17), 'Store B', 'Product 5', Decimal('313.95'), Decimal('279.389265'), Decimal('34.560735'))
# (datetime.date(2023, 3, 27), 'Store B', 'Product 8', Decimal('275.99'), Decimal('279.389265'), Decimal('-3.399265'))
# (datetime.date(2023, 8, 13), 'Store B', 'Product 4', Decimal('156.75'), Decimal('279.389265'), Decimal('-122.639265'))
# (datetime.date(2023, 8, 14), 'Store B', 'Product 8', Decimal('9.87'), Decimal('279.389265'), Decimal('-269.519265'))
# (datetime.date(2023, 3, 17), 'Store B', 'Product 5', Decimal('374.69'), Decimal('279.389265'), Decimal('95.300735'))
# (datetime.date(2023, 3, 30), 'Store B', 'Product 2', Decimal('231.16'), Decimal('279.389265'), Decimal('-48.229265'))
# (datetime.date(2023, 11, 16), 'Store B', 'Product 4', Decimal('611.88'), Decimal('279.389265'), Decimal('332.490735'))
# (datetime.date(2023, 12, 30), 'Store B', 'Product 10', Decimal('293.75'), Decimal('279.389265'), Decimal('14.360735'))
# (datetime.date(2023, 8, 6), 'Store B', 'Product 5', Decimal('221.18'), Decimal('279.389265'), Decimal('-58.209265'))
# (datetime.date(2023, 8, 14), 'Store B', 'Product 5', Decimal('271.26'), Decimal('279.389265'), Decimal('-8.129265'))
# (datetime.date(2023, 3, 16), 'Store B', 'Product 5', Decimal('551.01'), Decimal('279.389265'), Decimal('271.620735'))
# (datetime.date(2023, 3, 16), 'Store B', 'Product 4', Decimal('858.49'), Decimal('279.389265'), Decimal('579.100735'))
# (datetime.date(2023, 11, 18), 'Store B', 'Product 5', Decimal('132.22'), Decimal('279.389265'), Decimal('-147.169265'))
# (datetime.date(2023, 4, 2), 'Store B', 'Product 9', Decimal('52.13'), Decimal('279.389265'), Decimal('-227.259265'))
# (datetime.date(2023, 3, 14), 'Store B', 'Product 3', Decimal('97.94'), Decimal('279.389265'), Decimal('-181.449265'))
# (datetime.date(2023, 8, 5), 'Store B', 'Product 7', Decimal('18.59'), Decimal('279.389265'), Decimal('-260.799265'))
# (datetime.date(2023, 4, 3), 'Store B', 'Product 5', Decimal('55.47'), Decimal('279.389265'), Decimal('-223.919265'))
# (datetime.date(2023, 3, 13), 'Store B', 'Product 3', Decimal('190.77'), Decimal('279.389265'), Decimal('-88.619265'))
# (datetime.date(2023, 3, 13), 'Store B', 'Product 1', Decimal('201.39'), Decimal('279.389265'), Decimal('-77.999265'))
# (datetime.date(2023, 4, 5), 'Store B', 'Product 4', Decimal('208.71'), Decimal('279.389265'), Decimal('-70.679265'))
# (datetime.date(2023, 12, 27), 'Store B', 'Product 9', Decimal('281.34'), Decimal('279.389265'), Decimal('1.950735'))
# (datetime.date(2023, 11, 15), 'Store B', 'Product 4', Decimal('72.14'), Decimal('279.389265'), Decimal('-207.249265'))
# (datetime.date(2023, 8, 15), 'Store B', 'Product 2', Decimal('630.79'), Decimal('279.389265'), Decimal('351.400735'))
# (datetime.date(2023, 3, 11), 'Store B', 'Product 4', Decimal('470.48'), Decimal('279.389265'), Decimal('191.090735'))
# (datetime.date(2023, 11, 14), 'Store B', 'Product 9', Decimal('78.60'), Decimal('279.389265'), Decimal('-200.789265'))
# (datetime.date(2023, 4, 6), 'Store B', 'Product 5', Decimal('236.11'), Decimal('279.389265'), Decimal('-43.279265'))
# (datetime.date(2023, 8, 15), 'Store B', 'Product 5', Decimal('119.97'), Decimal('279.389265'), Decimal('-159.419265'))
# (datetime.date(2023, 11, 13), 'Store B', 'Product 2', Decimal('413.76'), Decimal('279.389265'), Decimal('134.370735'))
# (datetime.date(2023, 8, 3), 'Store B', 'Product 2', Decimal('99.96'), Decimal('279.389265'), Decimal('-179.429265'))
# (datetime.date(2023, 11, 13), 'Store B', 'Product 6', Decimal('208.37'), Decimal('279.389265'), Decimal('-71.019265'))
# (datetime.date(2023, 8, 17), 'Store B', 'Product 7', Decimal('266.63'), Decimal('279.389265'), Decimal('-12.759265'))
# (datetime.date(2023, 8, 18), 'Store B', 'Product 4', Decimal('179.14'), Decimal('279.389265'), Decimal('-100.249265'))
# (datetime.date(2023, 11, 12), 'Store B', 'Product 7', Decimal('534.21'), Decimal('279.389265'), Decimal('254.820735'))
# (datetime.date(2023, 4, 8), 'Store B', 'Product 2', Decimal('307.55'), Decimal('279.389265'), Decimal('28.160735'))
# (datetime.date(2023, 4, 9), 'Store B', 'Product 8', Decimal('285.50'), Decimal('279.389265'), Decimal('6.110735'))
# (datetime.date(2023, 8, 18), 'Store B', 'Product 6', Decimal('732.06'), Decimal('279.389265'), Decimal('452.670735'))
# (datetime.date(2023, 3, 10), 'Store B', 'Product 3', Decimal('345.29'), Decimal('279.389265'), Decimal('65.900735'))
# (datetime.date(2023, 7, 31), 'Store B', 'Product 9', Decimal('872.80'), Decimal('279.389265'), Decimal('593.410735'))
# (datetime.date(2023, 1, 4), 'Store B', 'Product 4', Decimal('333.90'), Decimal('279.389265'), Decimal('54.510735'))
# (datetime.date(2023, 3, 9), 'Store B', 'Product 3', Decimal('425.37'), Decimal('279.389265'), Decimal('145.980735'))
# (datetime.date(2023, 11, 10), 'Store B', 'Product 8', Decimal('420.27'), Decimal('279.389265'), Decimal('140.880735'))
# (datetime.date(2023, 3, 8), 'Store B', 'Product 10', Decimal('181.81'), Decimal('279.389265'), Decimal('-97.579265'))
# (datetime.date(2023, 11, 9), 'Store B', 'Product 5', Decimal('209.88'), Decimal('279.389265'), Decimal('-69.509265'))
# (datetime.date(2023, 8, 19), 'Store B', 'Product 2', Decimal('134.40'), Decimal('279.389265'), Decimal('-144.989265'))
# (datetime.date(2023, 1, 5), 'Store B', 'Product 7', Decimal('187.00'), Decimal('279.389265'), Decimal('-92.389265'))
# (datetime.date(2023, 8, 19), 'Store B', 'Product 9', Decimal('575.70'), Decimal('279.389265'), Decimal('296.310735'))
# (datetime.date(2023, 11, 7), 'Store B', 'Product 6', Decimal('67.58'), Decimal('279.389265'), Decimal('-211.809265'))
# (datetime.date(2023, 12, 24), 'Store B', 'Product 10', Decimal('454.57'), Decimal('279.389265'), Decimal('175.180735'))
# (datetime.date(2023, 4, 11), 'Store B', 'Product 6', Decimal('141.49'), Decimal('279.389265'), Decimal('-137.899265'))
# (datetime.date(2023, 11, 7), 'Store B', 'Product 1', Decimal('411.26'), Decimal('279.389265'), Decimal('131.870735'))
# (datetime.date(2023, 3, 6), 'Store B', 'Product 8', Decimal('68.39'), Decimal('279.389265'), Decimal('-210.999265'))
# (datetime.date(2023, 1, 8), 'Store B', 'Product 9', Decimal('103.77'), Decimal('279.389265'), Decimal('-175.619265'))
# (datetime.date(2023, 1, 8), 'Store B', 'Product 3', Decimal('564.96'), Decimal('279.389265'), Decimal('285.570735'))
# (datetime.date(2023, 7, 21), 'Store B', 'Product 4', Decimal('291.37'), Decimal('279.389265'), Decimal('11.980735'))
# (datetime.date(2023, 3, 4), 'Store B', 'Product 9', Decimal('138.73'), Decimal('279.389265'), Decimal('-140.659265'))
# (datetime.date(2023, 8, 24), 'Store B', 'Product 6', Decimal('78.05'), Decimal('279.389265'), Decimal('-201.339265'))
# (datetime.date(2023, 8, 24), 'Store B', 'Product 2', Decimal('194.00'), Decimal('279.389265'), Decimal('-85.389265'))
# (datetime.date(2023, 4, 14), 'Store B', 'Product 7', Decimal('61.73'), Decimal('279.389265'), Decimal('-217.659265'))
# (datetime.date(2023, 7, 20), 'Store B', 'Product 1', Decimal('558.45'), Decimal('279.389265'), Decimal('279.060735'))
# (datetime.date(2023, 11, 4), 'Store B', 'Product 9', Decimal('290.55'), Decimal('279.389265'), Decimal('11.160735'))
# (datetime.date(2023, 8, 25), 'Store B', 'Product 9', Decimal('76.49'), Decimal('279.389265'), Decimal('-202.899265'))
# (datetime.date(2023, 3, 4), 'Store B', 'Product 1', Decimal('281.84'), Decimal('279.389265'), Decimal('2.450735'))
# (datetime.date(2023, 4, 16), 'Store B', 'Product 2', Decimal('389.74'), Decimal('279.389265'), Decimal('110.350735'))
# (datetime.date(2023, 11, 21), 'Store B', 'Product 8', Decimal('732.25'), Decimal('279.389265'), Decimal('452.860735'))
# (datetime.date(2023, 4, 17), 'Store B', 'Product 1', Decimal('73.08'), Decimal('279.389265'), Decimal('-206.309265'))
# (datetime.date(2023, 1, 9), 'Store B', 'Product 6', Decimal('237.86'), Decimal('279.389265'), Decimal('-41.529265'))
# (datetime.date(2023, 7, 17), 'Store B', 'Product 1', Decimal('296.70'), Decimal('279.389265'), Decimal('17.310735'))
# (datetime.date(2023, 11, 22), 'Store B', 'Product 5', Decimal('367.72'), Decimal('279.389265'), Decimal('88.330735'))
# (datetime.date(2023, 11, 22), 'Store B', 'Product 10', Decimal('335.95'), Decimal('279.389265'), Decimal('56.560735'))
# (datetime.date(2023, 1, 10), 'Store B', 'Product 1', Decimal('48.23'), Decimal('279.389265'), Decimal('-231.159265'))
# (datetime.date(2023, 7, 17), 'Store B', 'Product 3', Decimal('36.57'), Decimal('279.389265'), Decimal('-242.819265'))
# (datetime.date(2023, 4, 21), 'Store B', 'Product 3', Decimal('652.29'), Decimal('279.389265'), Decimal('372.900735'))
# (datetime.date(2023, 3, 1), 'Store B', 'Product 7', Decimal('84.55'), Decimal('279.389265'), Decimal('-194.839265'))
# (datetime.date(2023, 4, 21), 'Store B', 'Product 10', Decimal('211.82'), Decimal('279.389265'), Decimal('-67.569265'))
# (datetime.date(2023, 8, 25), 'Store B', 'Product 10', Decimal('109.08'), Decimal('279.389265'), Decimal('-170.309265'))
# (datetime.date(2023, 4, 22), 'Store B', 'Product 9', Decimal('332.30'), Decimal('279.389265'), Decimal('52.910735'))
# (datetime.date(2023, 4, 22), 'Store B', 'Product 4', Decimal('386.08'), Decimal('279.389265'), Decimal('106.690735'))
# (datetime.date(2023, 4, 22), 'Store B', 'Product 1', Decimal('50.98'), Decimal('279.389265'), Decimal('-228.409265'))
# (datetime.date(2023, 8, 27), 'Store B', 'Product 10', Decimal('489.10'), Decimal('279.389265'), Decimal('209.710735'))
# (datetime.date(2023, 7, 11), 'Store B', 'Product 9', Decimal('100.36'), Decimal('279.389265'), Decimal('-179.029265'))
# (datetime.date(2023, 4, 23), 'Store B', 'Product 4', Decimal('74.28'), Decimal('279.389265'), Decimal('-205.109265'))
# (datetime.date(2023, 4, 23), 'Store B', 'Product 2', Decimal('154.16'), Decimal('279.389265'), Decimal('-125.229265'))
# (datetime.date(2023, 8, 28), 'Store B', 'Product 5', Decimal('209.79'), Decimal('279.389265'), Decimal('-69.599265'))
# (datetime.date(2023, 7, 11), 'Store B', 'Product 9', Decimal('135.24'), Decimal('279.389265'), Decimal('-144.149265'))
# (datetime.date(2023, 1, 14), 'Store B', 'Product 4', Decimal('416.41'), Decimal('279.389265'), Decimal('137.020735'))
# (datetime.date(2023, 7, 11), 'Store B', 'Product 1', Decimal('8.74'), Decimal('279.389265'), Decimal('-270.649265'))
# (datetime.date(2023, 12, 21), 'Store B', 'Product 8', Decimal('256.65'), Decimal('279.389265'), Decimal('-22.739265'))
# (datetime.date(2023, 10, 31), 'Store B', 'Product 3', Decimal('213.40'), Decimal('279.389265'), Decimal('-65.989265'))
# (datetime.date(2023, 7, 9), 'Store B', 'Product 10', Decimal('48.05'), Decimal('279.389265'), Decimal('-231.339265'))
# (datetime.date(2023, 12, 20), 'Store B', 'Product 8', Decimal('687.44'), Decimal('279.389265'), Decimal('408.050735'))
# (datetime.date(2023, 9, 3), 'Store B', 'Product 8', Decimal('510.84'), Decimal('279.389265'), Decimal('231.450735'))
# (datetime.date(2023, 2, 27), 'Store B', 'Product 6', Decimal('272.00'), Decimal('279.389265'), Decimal('-7.389265'))
# (datetime.date(2023, 5, 31), 'Store B', 'Product 6', Decimal('314.71'), Decimal('279.389265'), Decimal('35.320735'))
# (datetime.date(2023, 9, 4), 'Store B', 'Product 7', Decimal('128.56'), Decimal('279.389265'), Decimal('-150.829265'))
# (datetime.date(2023, 10, 30), 'Store B', 'Product 3', Decimal('135.25'), Decimal('279.389265'), Decimal('-144.139265'))
# (datetime.date(2023, 1, 15), 'Store B', 'Product 3', Decimal('88.28'), Decimal('279.389265'), Decimal('-191.109265'))
# (datetime.date(2023, 1, 16), 'Store B', 'Product 6', Decimal('481.33'), Decimal('279.389265'), Decimal('201.940735'))
# (datetime.date(2023, 7, 6), 'Store B', 'Product 8', Decimal('360.36'), Decimal('279.389265'), Decimal('80.970735'))
# (datetime.date(2023, 7, 6), 'Store B', 'Product 5', Decimal('315.01'), Decimal('279.389265'), Decimal('35.620735'))
# (datetime.date(2023, 2, 23), 'Store B', 'Product 4', Decimal('202.95'), Decimal('279.389265'), Decimal('-76.439265'))
# (datetime.date(2023, 11, 26), 'Store B', 'Product 10', Decimal('521.46'), Decimal('279.389265'), Decimal('242.070735'))
# (datetime.date(2023, 5, 1), 'Store B', 'Product 6', Decimal('250.95'), Decimal('279.389265'), Decimal('-28.439265'))
# (datetime.date(2023, 2, 23), 'Store B', 'Product 3', Decimal('848.86'), Decimal('279.389265'), Decimal('569.470735'))
# (datetime.date(2023, 7, 5), 'Store B', 'Product 4', Decimal('618.04'), Decimal('279.389265'), Decimal('338.650735'))
# (datetime.date(2023, 7, 5), 'Store B', 'Product 8', Decimal('276.42'), Decimal('279.389265'), Decimal('-2.969265'))
# (datetime.date(2023, 10, 23), 'Store B', 'Product 8', Decimal('254.38'), Decimal('279.389265'), Decimal('-25.009265'))
# (datetime.date(2023, 5, 2), 'Store B', 'Product 8', Decimal('578.22'), Decimal('279.389265'), Decimal('298.830735'))
# (datetime.date(2023, 9, 7), 'Store B', 'Product 6', Decimal('276.12'), Decimal('279.389265'), Decimal('-3.269265'))
# (datetime.date(2023, 5, 2), 'Store B', 'Product 10', Decimal('677.78'), Decimal('279.389265'), Decimal('398.390735'))
# (datetime.date(2023, 7, 3), 'Store B', 'Product 1', Decimal('750.07'), Decimal('279.389265'), Decimal('470.680735'))
# (datetime.date(2023, 1, 18), 'Store B', 'Product 7', Decimal('299.32'), Decimal('279.389265'), Decimal('19.930735'))
# (datetime.date(2023, 12, 31), 'Store B', 'Product 6', Decimal('507.75'), Decimal('279.389265'), Decimal('228.360735'))
# (datetime.date(2023, 5, 5), 'Store B', 'Product 1', Decimal('377.84'), Decimal('279.389265'), Decimal('98.450735'))
# (datetime.date(2023, 6, 29), 'Store B', 'Product 5', Decimal('249.22'), Decimal('279.389265'), Decimal('-30.169265'))
# (datetime.date(2023, 10, 20), 'Store B', 'Product 3', Decimal('140.93'), Decimal('279.389265'), Decimal('-138.459265'))
# (datetime.date(2023, 10, 19), 'Store B', 'Product 2', Decimal('633.28'), Decimal('279.389265'), Decimal('353.890735'))
# (datetime.date(2023, 5, 6), 'Store B', 'Product 7', Decimal('388.20'), Decimal('279.389265'), Decimal('108.810735'))
# (datetime.date(2023, 11, 27), 'Store B', 'Product 2', Decimal('243.23'), Decimal('279.389265'), Decimal('-36.159265'))
# (datetime.date(2023, 11, 27), 'Store B', 'Product 3', Decimal('30.48'), Decimal('279.389265'), Decimal('-248.909265'))
# (datetime.date(2023, 5, 7), 'Store B', 'Product 5', Decimal('155.23'), Decimal('279.389265'), Decimal('-124.159265'))
# (datetime.date(2023, 5, 7), 'Store B', 'Product 4', Decimal('713.43'), Decimal('279.389265'), Decimal('434.040735'))
# (datetime.date(2023, 12, 1), 'Store B', 'Product 2', Decimal('223.39'), Decimal('279.389265'), Decimal('-55.999265'))
# (datetime.date(2023, 5, 8), 'Store B', 'Product 4', Decimal('173.02'), Decimal('279.389265'), Decimal('-106.369265'))
# (datetime.date(2023, 5, 8), 'Store B', 'Product 5', Decimal('35.51'), Decimal('279.389265'), Decimal('-243.879265'))
# (datetime.date(2023, 1, 21), 'Store B', 'Product 8', Decimal('277.14'), Decimal('279.389265'), Decimal('-2.249265'))
# (datetime.date(2023, 2, 22), 'Store B', 'Product 7', Decimal('295.32'), Decimal('279.389265'), Decimal('15.930735'))
# (datetime.date(2023, 6, 28), 'Store B', 'Product 5', Decimal('179.07'), Decimal('279.389265'), Decimal('-100.319265'))
# (datetime.date(2023, 1, 21), 'Store B', 'Product 10', Decimal('27.49'), Decimal('279.389265'), Decimal('-251.899265'))
# (datetime.date(2023, 12, 16), 'Store B', 'Product 5', Decimal('153.43'), Decimal('279.389265'), Decimal('-125.959265'))
# (datetime.date(2023, 6, 26), 'Store B', 'Product 4', Decimal('40.36'), Decimal('279.389265'), Decimal('-239.029265'))
# (datetime.date(2023, 6, 26), 'Store B', 'Product 10', Decimal('102.49'), Decimal('279.389265'), Decimal('-176.899265'))
# (datetime.date(2023, 2, 21), 'Store B', 'Product 1', Decimal('187.61'), Decimal('279.389265'), Decimal('-91.779265'))
# (datetime.date(2023, 12, 2), 'Store B', 'Product 7', Decimal('670.42'), Decimal('279.389265'), Decimal('391.030735'))
# (datetime.date(2023, 6, 25), 'Store B', 'Product 7', Decimal('185.01'), Decimal('279.389265'), Decimal('-94.379265'))
# (datetime.date(2023, 9, 13), 'Store B', 'Product 1', Decimal('608.62'), Decimal('279.389265'), Decimal('329.230735'))
# (datetime.date(2023, 5, 12), 'Store B', 'Product 5', Decimal('76.32'), Decimal('279.389265'), Decimal('-203.069265'))
# (datetime.date(2023, 10, 11), 'Store B', 'Product 6', Decimal('110.15'), Decimal('279.389265'), Decimal('-169.239265'))
# (datetime.date(2023, 9, 14), 'Store B', 'Product 6', Decimal('309.88'), Decimal('279.389265'), Decimal('30.490735'))
# (datetime.date(2023, 5, 13), 'Store B', 'Product 7', Decimal('275.09'), Decimal('279.389265'), Decimal('-4.299265'))
# (datetime.date(2023, 5, 13), 'Store B', 'Product 2', Decimal('766.80'), Decimal('279.389265'), Decimal('487.410735'))
# (datetime.date(2023, 5, 13), 'Store B', 'Product 1', Decimal('989.00'), Decimal('279.389265'), Decimal('709.610735'))
# (datetime.date(2023, 6, 19), 'Store B', 'Product 9', Decimal('229.44'), Decimal('279.389265'), Decimal('-49.949265'))
# (datetime.date(2023, 6, 19), 'Store B', 'Product 2', Decimal('26.81'), Decimal('279.389265'), Decimal('-252.579265'))
# (datetime.date(2023, 9, 16), 'Store B', 'Product 8', Decimal('170.60'), Decimal('279.389265'), Decimal('-108.789265'))
# (datetime.date(2023, 12, 3), 'Store B', 'Product 6', Decimal('203.61'), Decimal('279.389265'), Decimal('-75.779265'))
# (datetime.date(2023, 12, 4), 'Store B', 'Product 2', Decimal('276.66'), Decimal('279.389265'), Decimal('-2.729265'))
# (datetime.date(2023, 6, 14), 'Store B', 'Product 5', Decimal('148.34'), Decimal('279.389265'), Decimal('-131.049265'))
# (datetime.date(2023, 12, 15), 'Store B', 'Product 6', Decimal('338.80'), Decimal('279.389265'), Decimal('59.410735'))
# (datetime.date(2023, 1, 29), 'Store B', 'Product 9', Decimal('69.31'), Decimal('279.389265'), Decimal('-210.079265'))
# (datetime.date(2023, 6, 12), 'Store B', 'Product 9', Decimal('27.94'), Decimal('279.389265'), Decimal('-251.449265'))
# (datetime.date(2023, 9, 21), 'Store B', 'Product 6', Decimal('567.93'), Decimal('279.389265'), Decimal('288.540735'))
# (datetime.date(2023, 6, 10), 'Store B', 'Product 5', Decimal('19.71'), Decimal('279.389265'), Decimal('-259.679265'))
# (datetime.date(2023, 12, 13), 'Store B', 'Product 10', Decimal('80.27'), Decimal('279.389265'), Decimal('-199.119265'))
# (datetime.date(2023, 9, 21), 'Store B', 'Product 4', Decimal('96.48'), Decimal('279.389265'), Decimal('-182.909265'))
# (datetime.date(2023, 9, 24), 'Store B', 'Product 2', Decimal('200.55'), Decimal('279.389265'), Decimal('-78.839265'))
# (datetime.date(2023, 5, 20), 'Store B', 'Product 3', Decimal('67.88'), Decimal('279.389265'), Decimal('-211.509265'))
# (datetime.date(2023, 10, 8), 'Store B', 'Product 4', Decimal('552.36'), Decimal('279.389265'), Decimal('272.970735'))
# (datetime.date(2023, 6, 9), 'Store B', 'Product 7', Decimal('128.31'), Decimal('279.389265'), Decimal('-151.079265'))
# (datetime.date(2023, 12, 12), 'Store B', 'Product 10', Decimal('177.38'), Decimal('279.389265'), Decimal('-102.009265'))
# (datetime.date(2023, 9, 25), 'Store B', 'Product 5', Decimal('620.97'), Decimal('279.389265'), Decimal('341.580735'))
# (datetime.date(2023, 2, 4), 'Store B', 'Product 1', Decimal('95.78'), Decimal('279.389265'), Decimal('-183.609265'))
# (datetime.date(2023, 2, 4), 'Store B', 'Product 7', Decimal('322.51'), Decimal('279.389265'), Decimal('43.120735'))
# (datetime.date(2023, 2, 12), 'Store B', 'Product 2', Decimal('348.18'), Decimal('279.389265'), Decimal('68.790735'))
# (datetime.date(2023, 12, 6), 'Store B', 'Product 4', Decimal('207.61'), Decimal('279.389265'), Decimal('-71.779265'))
# (datetime.date(2023, 10, 7), 'Store B', 'Product 1', Decimal('35.90'), Decimal('279.389265'), Decimal('-243.489265'))
# (datetime.date(2023, 2, 11), 'Store B', 'Product 7', Decimal('334.29'), Decimal('279.389265'), Decimal('54.900735'))
# (datetime.date(2023, 2, 11), 'Store B', 'Product 3', Decimal('246.49'), Decimal('279.389265'), Decimal('-32.899265'))
# (datetime.date(2023, 12, 11), 'Store B', 'Product 10', Decimal('583.86'), Decimal('279.389265'), Decimal('304.470735'))
# (datetime.date(2023, 2, 11), 'Store B', 'Product 6', Decimal('459.05'), Decimal('279.389265'), Decimal('179.660735'))
# (datetime.date(2023, 5, 24), 'Store B', 'Product 1', Decimal('125.13'), Decimal('279.389265'), Decimal('-154.259265'))
# (datetime.date(2023, 9, 28), 'Store B', 'Product 8', Decimal('123.87'), Decimal('279.389265'), Decimal('-155.519265'))
# (datetime.date(2023, 2, 10), 'Store B', 'Product 1', Decimal('316.50'), Decimal('279.389265'), Decimal('37.110735'))
# (datetime.date(2023, 6, 3), 'Store B', 'Product 9', Decimal('157.77'), Decimal('279.389265'), Decimal('-121.619265'))
# (datetime.date(2023, 5, 25), 'Store B', 'Product 4', Decimal('114.04'), Decimal('279.389265'), Decimal('-165.349265'))
# (datetime.date(2023, 2, 8), 'Store B', 'Product 6', Decimal('220.99'), Decimal('279.389265'), Decimal('-58.399265'))
# (datetime.date(2023, 6, 2), 'Store B', 'Product 10', Decimal('350.16'), Decimal('279.389265'), Decimal('70.770735'))
# (datetime.date(2023, 5, 26), 'Store B', 'Product 6', Decimal('190.96'), Decimal('279.389265'), Decimal('-88.429265'))
# (datetime.date(2023, 5, 26), 'Store B', 'Product 6', Decimal('29.41'), Decimal('279.389265'), Decimal('-249.979265'))
# (datetime.date(2023, 12, 7), 'Store B', 'Product 5', Decimal('94.34'), Decimal('279.389265'), Decimal('-185.049265'))
# (datetime.date(2023, 5, 27), 'Store B', 'Product 3', Decimal('551.88'), Decimal('279.389265'), Decimal('272.490735'))
# (datetime.date(2023, 5, 27), 'Store B', 'Product 2', Decimal('325.26'), Decimal('279.389265'), Decimal('45.870735'))
# (datetime.date(2023, 10, 4), 'Store B', 'Product 2', Decimal('170.20'), Decimal('279.389265'), Decimal('-109.189265'))
# (datetime.date(2023, 6, 1), 'Store B', 'Product 4', Decimal('453.08'), Decimal('279.389265'), Decimal('173.690735'))
# (datetime.date(2023, 10, 4), 'Store B', 'Product 4', Decimal('203.66'), Decimal('279.389265'), Decimal('-75.729265'))
# (datetime.date(2023, 10, 4), 'Store B', 'Product 7', Decimal('589.34'), Decimal('279.389265'), Decimal('309.950735'))
# (datetime.date(2023, 10, 2), 'Store B', 'Product 5', Decimal('693.52'), Decimal('279.389265'), Decimal('414.130735'))
# (datetime.date(2023, 10, 2), 'Store B', 'Product 6', Decimal('119.78'), Decimal('279.389265'), Decimal('-159.609265'))
# (datetime.date(2023, 5, 28), 'Store B', 'Product 9', Decimal('252.36'), Decimal('279.389265'), Decimal('-27.029265'))
# ...
# (datetime.date(2023, 9, 21), 'Store E', 'Product 3', Decimal('578.51'), Decimal('280.768155'), Decimal('297.741845'))
# (datetime.date(2023, 9, 19), 'Store E', 'Product 3', Decimal('255.30'), Decimal('280.768155'), Decimal('-25.468155'))
# (datetime.date(2023, 4, 8), 'Store E', 'Product 7', Decimal('467.26'), Decimal('280.768155'), Decimal('186.491845'))
# (datetime.date(2023, 9, 19), 'Store E', 'Product 5', Decimal('142.93'), Decimal('280.768155'), Decimal('-137.838155'))
# (datetime.date(2023, 6, 12), 'Store E', 'Product 5', Decimal('294.99'), Decimal('280.768155'), Decimal('14.221845'))
# (datetime.date(2023, 4, 6), 'Store E', 'Product 1', Decimal('90.25'), Decimal('280.768155'), Decimal('-190.518155'))
# (datetime.date(2023, 4, 6), 'Store E', 'Product 4', Decimal('103.21'), Decimal('280.768155'), Decimal('-177.558155'))
# (datetime.date(2023, 4, 6), 'Store E', 'Product 10', Decimal('355.40'), Decimal('280.768155'), Decimal('74.631845'))
# (datetime.date(2023, 4, 6), 'Store E', 'Product 6', Decimal('220.68'), Decimal('280.768155'), Decimal('-60.088155'))
# (datetime.date(2023, 11, 14), 'Store E', 'Product 10', Decimal('25.07'), Decimal('280.768155'), Decimal('-255.698155'))
# (datetime.date(2023, 9, 17), 'Store E', 'Product 7', Decimal('28.52'), Decimal('280.768155'), Decimal('-252.248155'))
# (datetime.date(2023, 4, 5), 'Store E', 'Product 7', Decimal('447.52'), Decimal('280.768155'), Decimal('166.751845'))
# (datetime.date(2023, 4, 5), 'Store E', 'Product 5', Decimal('576.13'), Decimal('280.768155'), Decimal('295.361845'))
# (datetime.date(2023, 6, 13), 'Store E', 'Product 4', Decimal('158.51'), Decimal('280.768155'), Decimal('-122.258155'))
# (datetime.date(2023, 3, 31), 'Store E', 'Product 2', Decimal('136.07'), Decimal('280.768155'), Decimal('-144.698155'))
# (datetime.date(2023, 9, 16), 'Store E', 'Product 3', Decimal('470.70'), Decimal('280.768155'), Decimal('189.931845'))
# (datetime.date(2023, 11, 16), 'Store E', 'Product 4', Decimal('344.42'), Decimal('280.768155'), Decimal('63.651845'))
# (datetime.date(2023, 3, 27), 'Store E', 'Product 8', Decimal('107.16'), Decimal('280.768155'), Decimal('-173.608155'))
# (datetime.date(2023, 6, 14), 'Store E', 'Product 6', Decimal('55.12'), Decimal('280.768155'), Decimal('-225.648155'))
# (datetime.date(2023, 3, 19), 'Store E', 'Product 10', Decimal('78.58'), Decimal('280.768155'), Decimal('-202.188155'))
# (datetime.date(2023, 3, 16), 'Store E', 'Product 8', Decimal('222.00'), Decimal('280.768155'), Decimal('-58.768155'))
# (datetime.date(2023, 6, 18), 'Store E', 'Product 3', Decimal('45.36'), Decimal('280.768155'), Decimal('-235.408155'))
# (datetime.date(2023, 3, 10), 'Store E', 'Product 6', Decimal('405.15'), Decimal('280.768155'), Decimal('124.381845'))
# (datetime.date(2023, 6, 19), 'Store E', 'Product 1', Decimal('609.85'), Decimal('280.768155'), Decimal('329.081845'))
# (datetime.date(2023, 3, 6), 'Store E', 'Product 7', Decimal('96.33'), Decimal('280.768155'), Decimal('-184.438155'))
# (datetime.date(2023, 6, 20), 'Store E', 'Product 6', Decimal('346.35'), Decimal('280.768155'), Decimal('65.581845'))
# (datetime.date(2023, 6, 21), 'Store E', 'Product 3', Decimal('142.32'), Decimal('280.768155'), Decimal('-138.448155'))
# (datetime.date(2023, 6, 22), 'Store E', 'Product 3', Decimal('302.26'), Decimal('280.768155'), Decimal('21.491845'))
# (datetime.date(2023, 3, 3), 'Store E', 'Product 9', Decimal('675.95'), Decimal('280.768155'), Decimal('395.181845'))
# (datetime.date(2023, 11, 22), 'Store E', 'Product 8', Decimal('489.21'), Decimal('280.768155'), Decimal('208.441845'))
# (datetime.date(2023, 9, 12), 'Store E', 'Product 1', Decimal('335.27'), Decimal('280.768155'), Decimal('54.501845'))
# (datetime.date(2023, 9, 12), 'Store E', 'Product 10', Decimal('335.11'), Decimal('280.768155'), Decimal('54.341845'))
# (datetime.date(2023, 5, 11), 'Store E', 'Product 5', Decimal('489.08'), Decimal('280.768155'), Decimal('208.311845'))
# (datetime.date(2023, 3, 1), 'Store E', 'Product 4', Decimal('44.04'), Decimal('280.768155'), Decimal('-236.728155'))
# (datetime.date(2023, 2, 27), 'Store E', 'Product 6', Decimal('41.84'), Decimal('280.768155'), Decimal('-238.928155'))
# (datetime.date(2023, 2, 27), 'Store E', 'Product 3', Decimal('423.80'), Decimal('280.768155'), Decimal('143.031845'))
# (datetime.date(2023, 11, 24), 'Store E', 'Product 6', Decimal('45.04'), Decimal('280.768155'), Decimal('-235.728155'))
# (datetime.date(2023, 9, 11), 'Store E', 'Product 3', Decimal('447.34'), Decimal('280.768155'), Decimal('166.571845'))
# (datetime.date(2023, 2, 26), 'Store E', 'Product 10', Decimal('247.16'), Decimal('280.768155'), Decimal('-33.608155'))
# (datetime.date(2023, 2, 23), 'Store E', 'Product 9', Decimal('21.14'), Decimal('280.768155'), Decimal('-259.628155'))
# (datetime.date(2023, 9, 10), 'Store E', 'Product 1', Decimal('599.37'), Decimal('280.768155'), Decimal('318.601845'))
# (datetime.date(2023, 6, 23), 'Store E', 'Product 9', Decimal('210.48'), Decimal('280.768155'), Decimal('-70.288155'))
# (datetime.date(2023, 2, 22), 'Store E', 'Product 8', Decimal('120.77'), Decimal('280.768155'), Decimal('-159.998155'))
# (datetime.date(2023, 6, 23), 'Store E', 'Product 8', Decimal('794.55'), Decimal('280.768155'), Decimal('513.781845'))
# (datetime.date(2023, 11, 27), 'Store E', 'Product 6', Decimal('103.73'), Decimal('280.768155'), Decimal('-177.038155'))
# (datetime.date(2023, 6, 29), 'Store E', 'Product 3', Decimal('697.14'), Decimal('280.768155'), Decimal('416.371845'))
# (datetime.date(2023, 9, 9), 'Store E', 'Product 2', Decimal('34.77'), Decimal('280.768155'), Decimal('-245.998155'))
# (datetime.date(2023, 12, 1), 'Store E', 'Product 4', Decimal('687.71'), Decimal('280.768155'), Decimal('406.941845'))
# (datetime.date(2023, 9, 9), 'Store E', 'Product 4', Decimal('168.57'), Decimal('280.768155'), Decimal('-112.198155'))
# (datetime.date(2023, 2, 21), 'Store E', 'Product 8', Decimal('305.10'), Decimal('280.768155'), Decimal('24.331845'))
# (datetime.date(2023, 2, 20), 'Store E', 'Product 5', Decimal('383.88'), Decimal('280.768155'), Decimal('103.111845'))
# (datetime.date(2023, 2, 20), 'Store E', 'Product 6', Decimal('166.65'), Decimal('280.768155'), Decimal('-114.118155'))
# (datetime.date(2023, 2, 18), 'Store E', 'Product 5', Decimal('29.66'), Decimal('280.768155'), Decimal('-251.108155'))
# (datetime.date(2023, 12, 3), 'Store E', 'Product 1', Decimal('124.67'), Decimal('280.768155'), Decimal('-156.098155'))
# (datetime.date(2023, 6, 29), 'Store E', 'Product 9', Decimal('25.87'), Decimal('280.768155'), Decimal('-254.898155'))
# (datetime.date(2023, 6, 29), 'Store E', 'Product 4', Decimal('324.92'), Decimal('280.768155'), Decimal('44.151845'))
# (datetime.date(2023, 12, 4), 'Store E', 'Product 2', Decimal('153.20'), Decimal('280.768155'), Decimal('-127.568155'))
# (datetime.date(2023, 2, 16), 'Store E', 'Product 10', Decimal('96.29'), Decimal('280.768155'), Decimal('-184.478155'))
# (datetime.date(2023, 9, 8), 'Store E', 'Product 10', Decimal('746.35'), Decimal('280.768155'), Decimal('465.581845'))
# (datetime.date(2023, 1, 1), 'Store E', 'Product 4', Decimal('855.70'), Decimal('280.768155'), Decimal('574.931845'))
# (datetime.date(2023, 12, 6), 'Store E', 'Product 3', Decimal('201.43'), Decimal('280.768155'), Decimal('-79.338155'))
# (datetime.date(2023, 12, 6), 'Store E', 'Product 8', Decimal('64.08'), Decimal('280.768155'), Decimal('-216.688155'))
# (datetime.date(2023, 7, 3), 'Store E', 'Product 4', Decimal('183.47'), Decimal('280.768155'), Decimal('-97.298155'))
# (datetime.date(2023, 9, 6), 'Store E', 'Product 6', Decimal('847.40'), Decimal('280.768155'), Decimal('566.631845'))
# (datetime.date(2023, 2, 10), 'Store E', 'Product 3', Decimal('123.22'), Decimal('280.768155'), Decimal('-157.548155'))
# (datetime.date(2023, 2, 10), 'Store E', 'Product 2', Decimal('400.03'), Decimal('280.768155'), Decimal('119.261845'))
# (datetime.date(2023, 7, 6), 'Store E', 'Product 7', Decimal('275.65'), Decimal('280.768155'), Decimal('-5.118155'))
# (datetime.date(2023, 12, 7), 'Store E', 'Product 8', Decimal('749.65'), Decimal('280.768155'), Decimal('468.881845'))
# (datetime.date(2023, 2, 8), 'Store E', 'Product 7', Decimal('235.94'), Decimal('280.768155'), Decimal('-44.828155'))
# (datetime.date(2023, 12, 8), 'Store E', 'Product 7', Decimal('151.46'), Decimal('280.768155'), Decimal('-129.308155'))
# (datetime.date(2023, 2, 8), 'Store E', 'Product 8', Decimal('161.68'), Decimal('280.768155'), Decimal('-119.088155'))
# (datetime.date(2023, 7, 6), 'Store E', 'Product 1', Decimal('176.70'), Decimal('280.768155'), Decimal('-104.068155'))
# (datetime.date(2023, 7, 6), 'Store E', 'Product 3', Decimal('248.93'), Decimal('280.768155'), Decimal('-31.838155'))
# (datetime.date(2023, 9, 4), 'Store E', 'Product 4', Decimal('52.34'), Decimal('280.768155'), Decimal('-228.428155'))
# (datetime.date(2023, 2, 7), 'Store E', 'Product 7', Decimal('654.56'), Decimal('280.768155'), Decimal('373.791845'))
# (datetime.date(2023, 7, 7), 'Store E', 'Product 4', Decimal('30.54'), Decimal('280.768155'), Decimal('-250.228155'))
# (datetime.date(2023, 2, 6), 'Store E', 'Product 5', Decimal('417.21'), Decimal('280.768155'), Decimal('136.441845'))
# (datetime.date(2023, 9, 1), 'Store E', 'Product 2', Decimal('160.38'), Decimal('280.768155'), Decimal('-120.388155'))
# (datetime.date(2023, 2, 5), 'Store E', 'Product 1', Decimal('630.63'), Decimal('280.768155'), Decimal('349.861845'))
# (datetime.date(2023, 7, 8), 'Store E', 'Product 6', Decimal('265.94'), Decimal('280.768155'), Decimal('-14.828155'))
# (datetime.date(2023, 7, 9), 'Store E', 'Product 3', Decimal('232.00'), Decimal('280.768155'), Decimal('-48.768155'))
# (datetime.date(2023, 12, 12), 'Store E', 'Product 10', Decimal('36.12'), Decimal('280.768155'), Decimal('-244.648155'))
# (datetime.date(2023, 12, 12), 'Store E', 'Product 10', Decimal('308.17'), Decimal('280.768155'), Decimal('27.401845'))
# (datetime.date(2023, 2, 4), 'Store E', 'Product 5', Decimal('82.34'), Decimal('280.768155'), Decimal('-198.428155'))
# (datetime.date(2023, 12, 12), 'Store E', 'Product 10', Decimal('205.83'), Decimal('280.768155'), Decimal('-74.938155'))
# (datetime.date(2023, 7, 11), 'Store E', 'Product 9', Decimal('488.29'), Decimal('280.768155'), Decimal('207.521845'))
# (datetime.date(2023, 8, 29), 'Store E', 'Product 5', Decimal('283.22'), Decimal('280.768155'), Decimal('2.451845'))
# (datetime.date(2023, 7, 11), 'Store E', 'Product 2', Decimal('23.88'), Decimal('280.768155'), Decimal('-256.888155'))
# (datetime.date(2023, 8, 27), 'Store E', 'Product 1', Decimal('78.94'), Decimal('280.768155'), Decimal('-201.828155'))
# (datetime.date(2023, 1, 29), 'Store E', 'Product 1', Decimal('428.93'), Decimal('280.768155'), Decimal('148.161845'))
# (datetime.date(2023, 1, 28), 'Store E', 'Product 7', Decimal('338.60'), Decimal('280.768155'), Decimal('57.831845'))
# (datetime.date(2023, 8, 26), 'Store E', 'Product 1', Decimal('180.52'), Decimal('280.768155'), Decimal('-100.248155'))
# (datetime.date(2023, 7, 16), 'Store E', 'Product 6', Decimal('184.86'), Decimal('280.768155'), Decimal('-95.908155'))
# (datetime.date(2023, 12, 15), 'Store E', 'Product 9', Decimal('219.17'), Decimal('280.768155'), Decimal('-61.598155'))
# (datetime.date(2023, 8, 23), 'Store E', 'Product 1', Decimal('299.58'), Decimal('280.768155'), Decimal('18.811845'))
# (datetime.date(2023, 1, 23), 'Store E', 'Product 9', Decimal('193.78'), Decimal('280.768155'), Decimal('-86.988155'))
# (datetime.date(2023, 7, 22), 'Store E', 'Product 3', Decimal('307.11'), Decimal('280.768155'), Decimal('26.341845'))
# (datetime.date(2023, 12, 16), 'Store E', 'Product 7', Decimal('301.14'), Decimal('280.768155'), Decimal('20.371845'))
# (datetime.date(2023, 7, 24), 'Store E', 'Product 6', Decimal('506.62'), Decimal('280.768155'), Decimal('225.851845'))
# (datetime.date(2023, 8, 21), 'Store E', 'Product 6', Decimal('254.91'), Decimal('280.768155'), Decimal('-25.858155'))
# (datetime.date(2023, 12, 17), 'Store E', 'Product 5', Decimal('592.60'), Decimal('280.768155'), Decimal('311.831845'))
# (datetime.date(2023, 8, 21), 'Store E', 'Product 4', Decimal('20.47'), Decimal('280.768155'), Decimal('-260.298155'))
# (datetime.date(2023, 8, 21), 'Store E', 'Product 7', Decimal('451.51'), Decimal('280.768155'), Decimal('170.741845'))
# (datetime.date(2023, 7, 25), 'Store E', 'Product 4', Decimal('642.37'), Decimal('280.768155'), Decimal('361.601845'))
# (datetime.date(2023, 12, 18), 'Store E', 'Product 7', Decimal('230.90'), Decimal('280.768155'), Decimal('-49.868155'))
# (datetime.date(2023, 1, 15), 'Store E', 'Product 4', Decimal('559.88'), Decimal('280.768155'), Decimal('279.111845'))
# (datetime.date(2023, 12, 21), 'Store E', 'Product 5', Decimal('284.07'), Decimal('280.768155'), Decimal('3.301845'))
# (datetime.date(2023, 1, 14), 'Store E', 'Product 5', Decimal('203.59'), Decimal('280.768155'), Decimal('-77.178155'))
# (datetime.date(2023, 1, 13), 'Store E', 'Product 6', Decimal('485.72'), Decimal('280.768155'), Decimal('204.951845'))
# (datetime.date(2023, 1, 13), 'Store E', 'Product 10', Decimal('423.16'), Decimal('280.768155'), Decimal('142.391845'))
# (datetime.date(2023, 1, 12), 'Store E', 'Product 3', Decimal('269.20'), Decimal('280.768155'), Decimal('-11.568155'))
# (datetime.date(2023, 12, 23), 'Store E', 'Product 3', Decimal('66.25'), Decimal('280.768155'), Decimal('-214.518155'))
# (datetime.date(2023, 7, 25), 'Store E', 'Product 10', Decimal('71.79'), Decimal('280.768155'), Decimal('-208.978155'))
# (datetime.date(2023, 8, 19), 'Store E', 'Product 2', Decimal('154.62'), Decimal('280.768155'), Decimal('-126.148155'))
# (datetime.date(2023, 1, 7), 'Store E', 'Product 5', Decimal('217.70'), Decimal('280.768155'), Decimal('-63.068155'))
# (datetime.date(2023, 8, 1), 'Store E', 'Product 10', Decimal('75.57'), Decimal('280.768155'), Decimal('-205.198155'))
# (datetime.date(2023, 1, 5), 'Store E', 'Product 6', Decimal('84.13'), Decimal('280.768155'), Decimal('-196.638155'))
# (datetime.date(2023, 8, 2), 'Store E', 'Product 7', Decimal('443.80'), Decimal('280.768155'), Decimal('163.031845'))
# (datetime.date(2023, 8, 17), 'Store E', 'Product 8', Decimal('187.74'), Decimal('280.768155'), Decimal('-93.028155'))
# (datetime.date(2023, 8, 17), 'Store E', 'Product 4', Decimal('183.84'), Decimal('280.768155'), Decimal('-96.928155'))
# (datetime.date(2023, 8, 3), 'Store E', 'Product 4', Decimal('51.79'), Decimal('280.768155'), Decimal('-228.978155'))
# (datetime.date(2023, 8, 3), 'Store E', 'Product 10', Decimal('66.61'), Decimal('280.768155'), Decimal('-214.158155'))
# (datetime.date(2023, 12, 26), 'Store E', 'Product 5', Decimal('173.01'), Decimal('280.768155'), Decimal('-107.758155'))
# (datetime.date(2023, 8, 5), 'Store E', 'Product 10', Decimal('242.09'), Decimal('280.768155'), Decimal('-38.678155'))
# (datetime.date(2023, 8, 8), 'Store E', 'Product 8', Decimal('104.46'), Decimal('280.768155'), Decimal('-176.308155'))
# (datetime.date(2023, 12, 27), 'Store E', 'Product 10', Decimal('807.85'), Decimal('280.768155'), Decimal('527.081845'))
# (datetime.date(2023, 8, 8), 'Store E', 'Product 6', Decimal('33.61'), Decimal('280.768155'), Decimal('-247.158155'))
# (datetime.date(2023, 1, 1), 'Store E', 'Product 5', Decimal('812.51'), Decimal('280.768155'), Decimal('531.741845'))
# (datetime.date(2023, 8, 13), 'Store E', 'Product 1', Decimal('266.99'), Decimal('280.768155'), Decimal('-13.778155'))
# (datetime.date(2023, 8, 13), 'Store E', 'Product 3', Decimal('129.99'), Decimal('280.768155'), Decimal('-150.778155'))
# (datetime.date(2023, 8, 8), 'Store E', 'Product 10', Decimal('72.96'), Decimal('280.768155'), Decimal('-207.808155'))
# (datetime.date(2023, 8, 11), 'Store E', 'Product 7', Decimal('118.31'), Decimal('280.768155'), Decimal('-162.458155'))
# (datetime.date(2023, 12, 31), 'Store E', 'Product 4', Decimal('61.21'), Decimal('280.768155'), Decimal('-219.558155'))
# (datetime.date(2023, 7, 1), 'Store E', 'Product 5', Decimal('466.34'), Decimal('280.768155'), Decimal('185.571845'))
# (datetime.date(2023, 11, 22), 'Store E', 'Product 5', Decimal('457.90'), Decimal('280.768155'), Decimal('177.131845'))

# %% [markdown]
# ## Task 5: Pivot Tables and Cross-Tabulations
#
# - **Objective**: Reshape and summarize the data.
# - **Instructions**:

# %% [markdown]
# 1. **Pivot Table**: Write a SQL query that creates a pivot-like result where:
#      - Each row represents a `Store`.
#      - Each column represents a `Product`.
#      - The cell values are the **Total Sales** for the corresponding store and product.
#      - Hint: Use `CASE` expressions combined with aggregation to simulate pivoting.
#
# Solution :
# Here the task is to create the pivot table where each row represents the `Store` and each column represents the `Product` , we need to calculate the total sales per store and product level through the ivot table
# the hint given here is using the `case` expression
# - Pivot table in sql : it is used to summarize the large dataset into the smaller format , this will be usefull when we are analyzing the large datasets
# - now by using the `case` expression we will solve this task

# %%
conn = mysql.connector.connect(
    host=MYSQL_HOST,
    user=MYSQL_USER,
    database=DATABASE_NAME
)
cursor = conn.cursor()
cursor.execute("""SELECT Store,
  SUM(CASE WHEN Product = 'Product 1' THEN Sales ELSE 0 END) AS Product1_Sales,
  SUM(CASE WHEN Product = 'Product 2' THEN Sales ELSE 0 END) AS Product2_Sales,
  SUM(CASE WHEN Product = 'Product 3' THEN Sales ELSE 0 END) AS Product3_Sales,
  SUM(CASE WHEN Product = 'Product 4' THEN Sales ELSE 0 END) AS Product4_Sales,
  SUM(CASE WHEN Product = 'Product 5' THEN Sales ELSE 0 END) AS Product5_Sales,
  SUM(CASE WHEN Product = 'Product 6' THEN Sales ELSE 0 END) AS Product6_Sales,
  SUM(CASE WHEN Product = 'Product 7' THEN Sales ELSE 0 END) AS Product7_Sales,
  SUM(CASE WHEN Product = 'Product 8' THEN Sales ELSE 0 END) AS Product8_Sales,
  SUM(CASE WHEN Product = 'Product 9' THEN Sales ELSE 0 END) AS Product9_Sales,
  SUM(CASE WHEN Product = 'Product 10' THEN Sales ELSE 0 END) AS Product10_Sales
FROM sales_data
GROUP BY Store;
""")
result=cursor.fetchall()
for x in result:
    print(x)
conn.close()
# Out:
# ('Store D', Decimal('5684.21'), Decimal('4446.71'), Decimal('6241.96'), Decimal('4345.45'), Decimal('6274.37'), Decimal('3184.58'), Decimal('4264.62'), Decimal('6892.04'), Decimal('6390.47'), Decimal('6353.06'))
# ('Store B', Decimal('5417.12'), Decimal('5873.91'), Decimal('4636.64'), Decimal('8480.77'), Decimal('6038.92'), Decimal('6568.42'), Decimal('5259.88'), Decimal('5703.23'), Decimal('3911.83'), Decimal('5104.69'))
# ('Store E', Decimal('5463.62'), Decimal('3287.87'), Decimal('6511.09'), Decimal('8180.80'), Decimal('8545.16'), Decimal('5437.28'), Decimal('5824.53'), Decimal('5507.05'), Decimal('3089.77'), Decimal('5991.07'))
# ('Store A', Decimal('4215.80'), Decimal('6865.40'), Decimal('6720.01'), Decimal('6282.59'), Decimal('7729.20'), Decimal('4472.30'), Decimal('5394.99'), Decimal('5733.97'), Decimal('5139.31'), Decimal('5962.39'))
# ('Store C', Decimal('4883.85'), Decimal('5757.30'), Decimal('4948.81'), Decimal('8038.50'), Decimal('4697.12'), Decimal('5461.22'), Decimal('4186.06'), Decimal('7736.36'), Decimal('6684.95'), Decimal('4531.28'))

# %% [markdown]
# 2. **Cross-Tabulation**: Write a SQL query that returns a cross-tabulation displaying the **Transaction Count** for each combination of `Store` (rows) and `Product` (columns). Again, use `CASE` expressions or any pivot function available in your SQL dialect.
#
# Solution :
#
# Here the task is to write a sql query that returns a cross tabulation displaying the total transaction for each combination of Store and Product, Here also hint given is to use the case statment
# - Here we are going to count the total number of transactions for store and product level
# - here the store is used for rows
# - and Product is used for the columns
# - here we will use the `Case` statment to solve this task

# %%
conn = mysql.connector.connect(
    host=MYSQL_HOST,
    user=MYSQL_USER,
    database=DATABASE_NAME
)
cursor = conn.cursor()
cursor.execute("""SELECT Store,
  SUM(CASE WHEN Product = 'Product 1' THEN 1  END) AS Product1_Count,
  SUM(CASE WHEN Product = 'Product 2' THEN 1  END) AS Product2_Count,
  SUM(CASE WHEN Product = 'Product 3' THEN 1  END) AS Product3_Count,
  SUM(CASE WHEN Product = 'Product 4' THEN 1  END) AS Product4_Count,
  SUM(CASE WHEN Product = 'Product 5' THEN 1  END) AS Product5_Count,
  SUM(CASE WHEN Product = 'Product 6' THEN 1  END) AS Product6_Count,
  SUM(CASE WHEN Product = 'Product 7' THEN 1  END) AS Product7_Count,
  SUM(CASE WHEN Product = 'Product 8' THEN 1  END) AS Product8_Count,
  SUM(CASE WHEN Product = 'Product 9' THEN 1  END) AS Product9_Count,
  SUM(CASE WHEN Product = 'Product 10' THEN 1 END) AS Product10_Count
FROM sales_data
GROUP BY Store;
""")
result=cursor.fetchall()
for x in result:
    print(x)
conn.close()
# Out:
# ('Store D', Decimal('16'), Decimal('19'), Decimal('22'), Decimal('12'), Decimal('21'), Decimal('19'), Decimal('14'), Decimal('19'), Decimal('25'), Decimal('19'))
# ('Store B', Decimal('18'), Decimal('20'), Decimal('16'), Decimal('29'), Decimal('25'), Decimal('24'), Decimal('18'), Decimal('18'), Decimal('19'), Decimal('17'))
# ('Store E', Decimal('19'), Decimal('12'), Decimal('24'), Decimal('25'), Decimal('26'), Decimal('23'), Decimal('20'), Decimal('20'), Decimal('14'), Decimal('23'))
# ('Store A', Decimal('15'), Decimal('24'), Decimal('22'), Decimal('23'), Decimal('25'), Decimal('15'), Decimal('24'), Decimal('20'), Decimal('23'), Decimal('17'))
# ('Store C', Decimal('18'), Decimal('20'), Decimal('20'), Decimal('26'), Decimal('14'), Decimal('18'), Decimal('19'), Decimal('23'), Decimal('21'), Decimal('17'))
