# %% [markdown]
# # Pandas Assignment: Data Summarization and Transformation
#
# ## Overview
#
# In this assignment, we will apply the "split-apply-combine" paradigm using pandas to summarize and transform a dataset. we will perform various grouping operations, aggregations, transformations, and pivot table creations to extract meaningful insights from the data.
#
# ## Dataset
#
# First we will work with a CSV file named `sales_data.csv` containing retail sales data with the following columns:
# - **Date**: Date of the transaction.
# - **Store**: Store identifier.
# - **Product**: Product name or ID.
# - **Sales**: Revenue generated from the sale.
# - **Quantity**: Number of items sold.

# %% [markdown]
# # Tasks

# %% [markdown]
# ## Task 1: Basic Grouping and Aggregation
#
# - **Objective**: Group the data by `Store` and `Product` to compute summary statistics.

# %% [markdown]
#   1. Load the dataset into a pandas DataFrame.
#   - Here we are goign to load the dataset called as `sales_data.csv` it conatins:
#     * Date - this column contains the date of each transaction
#     * Store - This column conatins the names of the stores
#     * Product - This column conatins the product_id where each product is having
#     * Sales - This column conatins the profit gained by each sale in the store
#     * Quantity - this column contains the quantity of the items sold per each store
#   - To load the dataset we need to first import the pandas library as pd from the python
#     * To load the dataset using the pandas we are using the read_csv() function from the pandas

# %%
import pandas as pd

# %%
df=pd.read_csv('/Users/lalithavemalapalli/Desktop/data_science/sales_data.csv')
df
# Out:
#            Date    Store    Product   Sales  Quantity
# 0    2023-01-01  Store D  Product 8  115.44         4
# 1    2023-01-01  Store B  Product 6  379.50         8
# 2    2023-01-01  Store E  Product 4  855.70        10
# 3    2023-01-01  Store D  Product 8  495.19         7
# 4    2023-01-01  Store A  Product 5  109.13         3
# ..          ...      ...        ...     ...       ...
# 995  2023-12-31  Store B  Product 9   67.57         1
# 996  2023-12-31  Store D  Product 3   31.20         2
# 997  2023-12-31  Store E  Product 4   61.21         2
# 998  2023-12-31  Store B  Product 6  507.75         6
# 999  2023-12-31  Store A  Product 9   29.05         2
#
# [1000 rows x 5 columns]

# %% [markdown]
# 2. Group the DataFrame by `Store` and `Product`.
# - In this task we are grouping the dataframe using the Store and Product Columns of the Dataframe df
# - here for doing this task we are going to use the `groupby()` function of the python pandas.
# - It groups the dataframe using the `Store` and `product` columns

# %%
group=df.groupby([df['Store'],df['Product']])
group

# %% [markdown]
# 3. For each group, calculate:
#      - **Total Sales**: Sum of the `Sales` column.
#      - **Average Quantity Sold**: Mean of the `Quantity` column.
#      - **Transaction Count**: Number of transactions (i.e., count of rows).
#
# Solution :
#
# - Here we are going to first caluculate the total sales of each store
#   * To calculate the total sles of the each store we are going to use the `sum()` function of the python pandas
# - Next we are going to calculate the average quantity of the products sold
#   * To calculate the average quatity of the producst sold we are going to use the `mean()` function of the pandas
# - Finally we need to calculate the number of transactions occurred
#   * To calculate the total number of transactions per each rwo we are going to use the `count()` function from the pandas

# %%
group1=df['Sales'].groupby([df['Store'],df['Product']]).sum()

# %%
group2=df['Quantity'].groupby([df['Store'],df['Product']]).mean()

# %%
group3=df['Sales'].groupby([df['Store'],df['Product']]).count()

# %% [markdown]
#  4. Display the resulting summary DataFrame.
#
#  Solution :
# - Here group1 contains the sum fo total sales of the each store which is grouped by the store and product level
# - Next group2 contains the average quatity of the products sold by each store
# - At lastly group3 contains the total number of transactions per each store

# %%
group1
# Out:
# Store    Product
# Store A  Product 1     4215.80
#          Product 10    5962.39
#          Product 2     6865.40
#          Product 3     6720.01
#          Product 4     6282.59
#          Product 5     7729.20
#          Product 6     4472.30
#          Product 7     5394.99
#          Product 8     5733.97
#          Product 9     5139.31
# Store B  Product 1     5417.12
#          Product 10    5104.69
#          Product 2     5873.91
#          Product 3     4636.64
#          Product 4     8480.77
#          Product 5     6038.92
#          Product 6     6568.42
#          Product 7     5259.88
#          Product 8     5703.23
#          Product 9     3911.83
# Store C  Product 1     4883.85
#          Product 10    4531.28
#          Product 2     5757.30
#          Product 3     4948.81
#          Product 4     8038.50
#          Product 5     4697.12
#          Product 6     5461.22
#          Product 7     4186.06
#          Product 8     7736.36
# ...

# %%
group2
# Out:
# Store    Product
# Store A  Product 1     5.133333
#          Product 10    5.941176
#          Product 2     4.875000
#          Product 3     6.409091
#          Product 4     5.347826
#          Product 5     5.840000
#          Product 6     6.400000
#          Product 7     4.500000
#          Product 8     5.550000
#          Product 9     4.260870
# Store B  Product 1     4.944444
#          Product 10    5.647059
#          Product 2     6.600000
#          Product 3     5.375000
#          Product 4     4.896552
#          Product 5     5.080000
#          Product 6     5.625000
#          Product 7     4.611111
#          Product 8     5.277778
#          Product 9     4.473684
# Store C  Product 1     4.555556
#          Product 10    5.176471
#          Product 2     5.050000
#          Product 3     5.150000
#          Product 4     5.692308
#          Product 5     6.785714
#          Product 6     5.111111
#          Product 7     5.736842
# ...

# %%
group3
# Out:
# Store    Product
# Store A  Product 1     15
#          Product 10    17
#          Product 2     24
#          Product 3     22
#          Product 4     23
#          Product 5     25
#          Product 6     15
#          Product 7     24
#          Product 8     20
#          Product 9     23
# Store B  Product 1     18
#          Product 10    17
#          Product 2     20
#          Product 3     16
#          Product 4     29
#          Product 5     25
#          Product 6     24
#          Product 7     18
#          Product 8     18
#          Product 9     19
# Store C  Product 1     18
#          Product 10    17
#          Product 2     20
#          Product 3     20
#          Product 4     26
#          Product 5     14
#          Product 6     18
#          Product 7     19
#          Product 8     23
#          Product 9     21
# Store D  Product 1     16
#          Product 10    19
#          Product 2     19
#          Product 3     22
#          Product 4     12
# ...

# %% [markdown]
# ## Task 2: Multiple Aggregations with `.agg()`
#
# - **Objective**: Apply multiple aggregation functions to the grouped data.
# - **Instructions**:

# %% [markdown]
# 1. Continue with the grouping from Task 1.
#   2. Use the `.agg()` method to compute for each group:
#      - **Total Sales**
#      - **Mean Sales**
#      - **Standard Deviation of Sales**
#      - **Total Quantity Sold**
#
# Solution :
# - For calculating this we are using the `agg()` function from the pandas and passing each as an argument
#   * for calculating the total sales we use the `agg()` and pass the argument as `sum` to count the total number of sales per each store
#   * for calculating the mean / avg sales we are going to use the `agg()` function and pass the `mean` as an argument to find the average sales of each store
#   * for calculating the standard deviation of sales we are going to use the `agg()` function and going to pass the `std` as an argument to find the standard deviation of sales per each store and product combination
#   * for claculating the total quantity sold we are suing the `agg()` function and pass the `sum` as an argument

# %%
group1=df['Sales'].groupby([df['Store'],df['Product']]).agg(sum_of_sales=("sum"))
group2=df['Sales'].groupby([df['Store'],df['Product']]).agg(Average_sales=("mean"))
group3=df['Sales'].groupby([df['Store'],df['Product']]).agg(standard_dev_of_sales=("std"))
group4=df['Quantity'].groupby([df['Store'],df['Product']]).agg(total_quantity_sold=("sum"))

# %% [markdown]
# 3. Ensure that the resulting DataFrame has clearly named columns for each aggregation.
#
# Solution :
#
# In the adove code :
# - group1 : conatins the code that calculates the total sales per each store and product combination
# - group2 : contains the code that calculates the average sales per each store and product level
# - group3 : conatins the code that calculates the standard deviation of the sales per each store and product level
# - group4 : contains the code that calculate the total quantity of the products sold per each Store and the product level

# %%
group1
# Out:
#                     sum_of_sales
# Store   Product
# Store A Product 1        4215.80
#         Product 10       5962.39
#         Product 2        6865.40
#         Product 3        6720.01
#         Product 4        6282.59
#         Product 5        7729.20
#         Product 6        4472.30
#         Product 7        5394.99
#         Product 8        5733.97
#         Product 9        5139.31
# Store B Product 1        5417.12
#         Product 10       5104.69
#         Product 2        5873.91
#         Product 3        4636.64
#         Product 4        8480.77
#         Product 5        6038.92
#         Product 6        6568.42
#         Product 7        5259.88
#         Product 8        5703.23
#         Product 9        3911.83
# Store C Product 1        4883.85
#         Product 10       4531.28
#         Product 2        5757.30
#         Product 3        4948.81
#         Product 4        8038.50
#         Product 5        4697.12
#         Product 6        5461.22
# ...

# %%
group2
# Out:
#                     Average_sales
# Store   Product
# Store A Product 1      281.053333
#         Product 10     350.728824
#         Product 2      286.058333
#         Product 3      305.455000
#         Product 4      273.156087
#         Product 5      309.168000
#         Product 6      298.153333
#         Product 7      224.791250
#         Product 8      286.698500
#         Product 9      223.448261
# Store B Product 1      300.951111
#         Product 10     300.275882
#         Product 2      293.695500
#         Product 3      289.790000
#         Product 4      292.440345
#         Product 5      241.556800
#         Product 6      273.684167
#         Product 7      292.215556
#         Product 8      316.846111
#         Product 9      205.885789
# Store C Product 1      271.325000
#         Product 10     266.545882
#         Product 2      287.865000
#         Product 3      247.440500
#         Product 4      309.173077
#         Product 5      335.508571
# ...

# %%
group3
# Out:
#                     standard_dev_of_sales
# Store   Product
# Store A Product 1              259.516982
#         Product 10             274.669722
#         Product 2              243.078536
#         Product 3              224.234992
#         Product 4              238.796871
#         Product 5              314.125851
#         Product 6              237.475723
#         Product 7              197.699947
#         Product 8              219.284806
#         Product 9              185.906069
# Store B Product 1              274.876973
#         Product 10             203.038302
#         Product 2              194.085105
#         Product 3              249.187130
#         Product 4              224.594490
#         Product 5              173.389211
#         Product 6              176.655650
#         Product 7              186.225465
#         Product 8              202.657823
#         Product 9              209.646229
# Store C Product 1              235.851606
# ...

# %%
group4
# Out:
#                     total_quantity_sold
# Store   Product
# Store A Product 1                    77
#         Product 10                  101
#         Product 2                   117
#         Product 3                   141
#         Product 4                   123
#         Product 5                   146
#         Product 6                    96
#         Product 7                   108
#         Product 8                   111
#         Product 9                    98
# Store B Product 1                    89
#         Product 10                   96
#         Product 2                   132
#         Product 3                    86
#         Product 4                   142
#         Product 5                   127
#         Product 6                   135
#         Product 7                    83
#         Product 8                    95
#         Product 9                    85
# Store C Product 1                    82
#         Product 10                   88
# ...

# %% [markdown]
# ## Task 3: Custom Aggregation using `.apply()`
#
# - **Objective**: Implement a custom aggregation function for group-level analysis.
# - **Instructions**:

# %% [markdown]
# 1. Define a custom function that calculates the **Sales per Transaction** ratio for each group (i.e., total `Sales` divided by the number of transactions).
#
# Solution :
# Here the task is to calculate the sales per each transaction for each group means each store for this:
# - first we need to create the function called as sales_per_transaction
# - The in that we need to create the variable called num_of_sales ih this variable we are calculating the total numner of sales using the `sum()` function
# - then we need to create the variable called the num_of_transaction in this we are calculating the total numnber of transaction per each sale using the `sum()` function
# - then we will use the `apply()` function to apply this function to the dataframe

# %%
def sales_per_transaction(df):
    return df.groupby(df['Store']).apply(lambda x : x['Sales'].sum() / x['Sales'].count())
sales_per_transaction(df)
# Out:
# /var/folders/2k/szdhz6bx58d6z_hbxdm_sn6m0000gn/T/ipykernel_88819/4012903028.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(df['Store']).apply(lambda x : x['Sales'].sum() / x['Sales'].count())
# Store
# Store A    281.326731
# Store B    279.389265
# Store C    290.435969
# Store D    290.739086
# Store E    280.768155
# dtype: float64

# %% [markdown]
#  2. Apply this custom function to each group.
#
#  solution :
#  - apply the above sales_per_transaction() function to all the groups in the dataframe is the task here ,
#    * To do that task forst we need to see what are the columns included in the dataframe :
#         - Date
#         - Store (already done with this column)
#         - Product
#         - Quantity
#     * Now to apply this function to the each column of the dataframe we need to add the columns near the group by function

# %%
def sales_per_transaction(df):
    return df.groupby(df['Date']).apply(lambda x : x['Sales'].sum() / x['Sales'].count())
sales_per_transaction(df)
# Out:
# /var/folders/2k/szdhz6bx58d6z_hbxdm_sn6m0000gn/T/ipykernel_88819/1408477398.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(df['Date']).apply(lambda x : x['Sales'].sum() / x['Sales'].count())
# Date
# 2023-01-01    461.245000
# 2023-01-02    291.310000
# 2023-01-03     72.520000
# 2023-01-04    218.950000
# 2023-01-05    103.356000
#                  ...
# 2023-12-26    246.260000
# 2023-12-27    544.595000
# 2023-12-29    125.080000
# 2023-12-30    168.330000
# 2023-12-31    155.296667
# Length: 336, dtype: float64

# %%
def sales_per_transaction(df):
    return df.groupby(df['Product']).apply(lambda x : x['Sales'].sum() / x['Sales'].count())
sales_per_transaction(df)
# Out:
# /var/folders/2k/szdhz6bx58d6z_hbxdm_sn6m0000gn/T/ipykernel_88819/1818977641.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(df['Product']).apply(lambda x : x['Sales'].sum() / x['Sales'].count())
# Product
# Product 1     298.425581
# Product 10    300.456882
# Product 2     276.117789
# Product 3     279.408750
# Product 4     307.200957
# Product 5     299.862793
# Product 6     253.775758
# Product 7     262.421895
# Product 8     315.726500
# Product 9     247.218922
# dtype: float64

# %% [markdown]
# - By analysing the sales per transaction using the quantity does not able to understandable by the user rather tahn we can analyse this by adding the products column also that looks understandable

# %%
def sales_per_transaction(df):
    return df.groupby(df['Quantity']).apply(lambda x : x['Sales'].sum() / x['Sales'].count())
sales_per_transaction(df)
# Out:
# /var/folders/2k/szdhz6bx58d6z_hbxdm_sn6m0000gn/T/ipykernel_88819/3650537959.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby(df['Quantity']).apply(lambda x : x['Sales'].sum() / x['Sales'].count())
# Quantity
# 1      47.061913
# 2     110.571368
# 3     153.988558
# 4     194.049588
# 5     273.513431
# 6     301.925146
# 7     348.706703
# 8     422.960286
# 9     474.519604
# 10    580.830230
# dtype: float64

# %% [markdown]
# - This code tells that per product for how much quantity the sales_per_transaction as been happend

# %%
def sales_per_transaction(df):
    return df.groupby([df['Product'],df['Quantity']]).apply(lambda x : x['Sales'].sum() / x['Sales'].count())
sales_per_transaction(df)
# Out:
# /var/folders/2k/szdhz6bx58d6z_hbxdm_sn6m0000gn/T/ipykernel_88819/1233599766.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby([df['Product'],df['Quantity']]).apply(lambda x : x['Sales'].sum() / x['Sales'].count())
# Product    Quantity
# Product 1  1            37.455385
#            2           118.387500
#            3           146.778889
#            4           292.406667
#            5           311.532500
#                           ...
# Product 9  6           239.225000
#            7           215.662500
#            8           284.078182
#            9           507.028000
#            10          703.550000
# Length: 100, dtype: float64

# %% [markdown]
# - we can also add all the columns in the same code , by doing this it will reduce the lines if code and it is easy to understand and it will increase readability

# %%
def sales_per_transaction(df):
    return df.groupby([df['Date'],df['Store'],df['Product'],df['Quantity']]).apply(lambda x : x['Sales'].sum() / x['Sales'].count())
sales_per_transaction(df)
# Out:
# /var/folders/2k/szdhz6bx58d6z_hbxdm_sn6m0000gn/T/ipykernel_88819/582251245.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby([df['Date'],df['Store'],df['Product'],df['Quantity']]).apply(lambda x : x['Sales'].sum() / x['Sales'].count())
# Date        Store    Product    Quantity
# 2023-01-01  Store A  Product 5  3           109.13
#             Store B  Product 6  8           379.50
#             Store D  Product 8  4           115.44
#                                 7           495.19
#             Store E  Product 4  10          855.70
#                                              ...
# 2023-12-31  Store B  Product 5  5           235.00
# ...

# %% [markdown]
# ## Task 4: Data Transformation with Group Transforms
#
# - **Objective**: Broadcast group-level statistics back to the original DataFrame.
# - **Instructions**:

# %% [markdown]
#  1. Compute the average `Sales` for each `Store`.
#
#  Solution :
# here the task is to compute the average of sales per each Store on the dataframe
# - we can do this task using the aggregate function mean()
# - First we need to group the dtaframe per store using the groupby function
# - Then calculate the sales per each store

# %%
grouped=df['Sales'].groupby(df['Store']).mean()
grouped
# Out:
# Store
# Store A    281.326731
# Store B    279.389265
# Store C    290.435969
# Store D    290.739086
# Store E    280.768155
# Name: Sales, dtype: float64

# %% [markdown]
#  2. Use the `.transform()` method to create a new column in the original DataFrame that contains the average `Sales` for the corresponding `Store`.
#
#  Solution :
#
# - Here the task is to create the new column in the original dataframe called average_sales_per_store in this column it contains the data related to the average sales per store
# - Here we will achieve this task by using the transform function and then calculate the average sales per store by using the mean function of the python pandas
# - Here we are creating the new column in the dataframe which contains the average of the sales per each store level

# %%
group=df['Sales'].groupby(df['Store'])
def get_mean(x):
    return x.mean()
df['Average_sales']=group.transform(get_mean)

# %%
df
# Out:
#            Date    Store    Product   Sales  Quantity  transform+column  \
# 0    2023-01-01  Store D  Product 8  115.44         4        290.739086
# 1    2023-01-01  Store B  Product 6  379.50         8        279.389265
# 2    2023-01-01  Store E  Product 4  855.70        10        280.768155
# 3    2023-01-01  Store D  Product 8  495.19         7        290.739086
# 4    2023-01-01  Store A  Product 5  109.13         3        281.326731
# ..          ...      ...        ...     ...       ...               ...
# 995  2023-12-31  Store B  Product 9   67.57         1        279.389265
# 996  2023-12-31  Store D  Product 3   31.20         2        290.739086
# 997  2023-12-31  Store E  Product 4   61.21         2        280.768155
# 998  2023-12-31  Store B  Product 6  507.75         6        279.389265
# 999  2023-12-31  Store A  Product 9   29.05         2        281.326731
#
#      transform_column  Average_sales
# 0          290.739086     290.739086
# ...

# %% [markdown]
# - Here we are droping the column which is added by mistakenly using the drop() function in the python

# %%
df.drop(columns=['transform+column','transform_column'])
# Out:
#            Date    Store    Product   Sales  Quantity  Average_sales  \
# 0    2023-01-01  Store D  Product 8  115.44         4     290.739086
# 1    2023-01-01  Store B  Product 6  379.50         8     279.389265
# 2    2023-01-01  Store E  Product 4  855.70        10     280.768155
# 3    2023-01-01  Store D  Product 8  495.19         7     290.739086
# 4    2023-01-01  Store A  Product 5  109.13         3     281.326731
# ..          ...      ...        ...     ...       ...            ...
# 995  2023-12-31  Store B  Product 9   67.57         1     279.389265
# 996  2023-12-31  Store D  Product 3   31.20         2     290.739086
# 997  2023-12-31  Store E  Product 4   61.21         2     280.768155
# 998  2023-12-31  Store B  Product 6  507.75         6     279.389265
# 999  2023-12-31  Store A  Product 9   29.05         2     281.326731
#
#      diff_of_sales
# 0      -175.299086
# 1       100.110735
# 2       574.931845
# 3       204.450914
# 4      -172.196731
# ...

# %% [markdown]
# 3. Create another column that shows the difference between each individual `Sales` value and the store's average `Sales`.
#
# Soluntion:
# Now the original dataframe containing the columns are :
# - Date : date of each transaction
# - Store : Different Stores
# - Product : different products named with their product_id
# - Sales : sales or each store
# - Quantity : Quantity of the products sold at store level
# - Average_sales : this is the additionla column which is added manually , this column contaions the average sales per each store
#
# Now here the task is to create the new column called diff_of_sales that shows  the difference between the individual sales and the store's average sales

# %%
def difference_of_sales(df):
    return (df['Sales']-df['Average_sales'])
df['diff_of_sales']=difference_of_sales(df)

# %%
df.drop(columns=['transform+column','transform_column'])
# Out:
#            Date    Store    Product   Sales  Quantity  Average_sales  \
# 0    2023-01-01  Store D  Product 8  115.44         4     290.739086
# 1    2023-01-01  Store B  Product 6  379.50         8     279.389265
# 2    2023-01-01  Store E  Product 4  855.70        10     280.768155
# 3    2023-01-01  Store D  Product 8  495.19         7     290.739086
# 4    2023-01-01  Store A  Product 5  109.13         3     281.326731
# ..          ...      ...        ...     ...       ...            ...
# 995  2023-12-31  Store B  Product 9   67.57         1     279.389265
# 996  2023-12-31  Store D  Product 3   31.20         2     290.739086
# 997  2023-12-31  Store E  Product 4   61.21         2     280.768155
# 998  2023-12-31  Store B  Product 6  507.75         6     279.389265
# 999  2023-12-31  Store A  Product 9   29.05         2     281.326731
#
#      diff_of_sales
# 0      -175.299086
# 1       100.110735
# 2       574.931845
# 3       204.450914
# 4      -172.196731
# ...

# %% [markdown]
# ## Task 5: Pivot Tables and Cross-Tabulation
#
# - **Objective**: Reshape and summarize data using pivot tables and cross-tabulations.
# - **Instructions**:

# %% [markdown]
# 1. Create a pivot table that displays **Total Sales** with `Store` as rows and `Product` as columns.
#
# Solution:
#
# Here the task is to create the pivot table that disply the `total sales` using the store and product table
# - First we need to know which are the rows we need to use to complete this task
# - they only mentioned that we need to use the Store column for the rows and Product column as the column values
# - Then the next task is to display the total sales for this we use the Sales column from the dataframe
# - Then we can create the pivot table using the python pandas pivot_table() function

# %%
pivot=df.pivot_table(index=['Store'],columns=['Product'],values=['Sales'])
pivot
# Out:
#               Sales                                                  \
# Product   Product 1  Product 10   Product 2   Product 3   Product 4
# Store
# Store A  281.053333  350.728824  286.058333  305.455000  273.156087
# Store B  300.951111  300.275882  293.695500  289.790000  292.440345
# Store C  271.325000  266.545882  287.865000  247.440500  309.173077
# Store D  355.263125  334.371579  234.037368  283.725455  362.120833
# Store E  287.558947  260.481304  273.989167  271.295417  327.232000
#
#
# Product   Product 5   Product 6   Product 7   Product 8   Product 9
# Store
# Store A  309.168000  298.153333  224.791250  286.698500  223.448261
# Store B  241.556800  273.684167  292.215556  316.846111  205.885789
# Store C  335.508571  303.401111  220.318947  336.363478  318.330952
# Store D  298.779524  167.609474  304.615714  362.738947  255.618800
# Store E  328.660000  236.403478  291.226500  275.352500  220.697857

# %% [markdown]
# 2. Generate a cross-tabulation to display the **Transaction Count** for each combination of `Store` (rows) and `Product` (columns).
#
# Solution:
#
# Here the task is to generate the cross-tabulation to display the trasaction cout for each combination of Store and Product level
# - Here to generate the cross-tabulation we use the python pandas `crosstab()` function
# - And pass Store as row value and Product as column value

# %%
pd.crosstab(df['Store'],df['Product'])
# Out:
# Product  Product 1  Product 10  Product 2  Product 3  Product 4  Product 5  \
# Store
# Store A         15          17         24         22         23         25
# Store B         18          17         20         16         29         25
# Store C         18          17         20         20         26         14
# Store D         16          19         19         22         12         21
# Store E         19          23         12         24         25         26
#
# Product  Product 6  Product 7  Product 8  Product 9
# Store
# Store A         15         24         20         23
# Store B         24         18         18         19
# Store C         18         19         23         21
# Store D         19         14         19         25
# Store E         23         20         20         14

# %% [markdown]
# 3. Optionally, use visualization (e.g., matplotlib) to highlight trends across different stores and products.

# %% [markdown]
# Firstly we are visualizing the sales per each store using the bar chart of python matplotlib library
# - here we are passing the store as x value
# - And sales for y value

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(df['Store'],df['Sales'])
plt.xlabel('Stores')
plt.ylabel('Sales_per_each_store')
plt.title="Sales per each store"

# %%
pivot.plot(kind='bar',figsize=(15,8))
plt.xlabel("Stores")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')
